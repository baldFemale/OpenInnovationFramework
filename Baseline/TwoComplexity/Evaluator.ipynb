# %%
# heatmap figure to replace the 3D surface
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data
x = np.linspace(0, 10, 100)  # Values of x
y = np.linspace(0, 5, 50)    # Values of y
X, Y = np.meshgrid(x, y)     # Create a grid of x and y values
z = np.sin(X) + np.cos(Y)    # Compute the values of z based on x and y
# Create the 2D color plot
plt.pcolormesh(x, y, z, cmap='jet')
plt.colorbar()  # Add a colorbar for reference

# Set the axis labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('2D Color Plot Using Matplotlib')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
# Need a heatmap; X: K; Y: Alpha
# Together: Complexity in depth vs. Complexity in breadth
K_list = [0, 1, 2, 3, 4, 5, 6, 7, 8]
alpha_list = np.arange(0.10, 0.50, step=0.025, dtype=float).tolist()
alpha_list = [f'{num:.3f}'.rstrip('0').rstrip('.') for num in alpha_list]
data_folder = r"E:\data\gst-0815-23\Pre-Test\TwoComplexity_01"
g_fitness_across_alpha, s_fitness_across_alpha = [], []
for alpha in alpha_list:
    g_file = data_folder + r"\g_performance_across_K_alpha_{0}".format(alpha)
    s_file = data_folder + r"\s_performance_across_K_alpha_{0}".format(alpha)
    
    with open(g_file, 'rb') as infile:
        g_fitness = pickle.load(infile)
    with open(s_file, 'rb') as infile:
        s_fitness = pickle.load(infile)
    g_fitness_across_alpha.append(g_fitness)
    s_fitness_across_alpha.append(s_fitness)

print(np.array(g_fitness_across_alpha).shape)
print(g_fitness_across_alpha)
print(s_fitness_across_alpha)
# Out:
# (16, 9)
# [[0.9085121309547999, 0.8725222280553686, 0.8468180778406793, 0.8216231490373166, 0.8054221448393706, 0.7866724312544484, 0.7722229734569346, 0.7573770417711203, 0.7405948520327315], [0.8896330455788859, 0.8531423382842419, 0.8298928353809798, 0.8105477641517622, 0.792382765284642, 0.7755846295164759, 0.7636958960160837, 0.7476316803387415, 0.7332686408376707], [0.8719600900580785, 0.8380578916982598, 0.815161648264901, 0.7983536413971056, 0.7803079027333257, 0.7628715306692787, 0.7489467101784308
.9453562857337694, 0.9084454005100586, 0.8805883936276326, 0.8586161938325891, 0.8362186294719506, 0.8183407257875486, 0.8005116062270838, 0.782456237530914], [0.9998974073813507, 0.9458771409334701, 0.9086183744723673, 0.8794936061387176, 0.8546831436706586, 0.8335226659836935, 0.8146121036940553, 0.7995680077435858, 0.7787515761536511], [0.9998874545493899, 0.9445098622160445, 0.909052953231831, 0.8786598591961146, 0.8556032430587058, 0.834791311867734, 0.8154174705055943, 0.7956849359183057, 0.7779371600203906], [0.999871354449249, 0.9454412249999952, 0.9047194566691769, 0.876713533098982, 0.8518445207916946, 0.8317296092403853, 0.8123373664946699, 0.7937677469641078, 0.7801379665861562], [0.9998926662147649, 0.9427171929634818, 0.9048782843350485, 0.8769613714259448, 0.8528103581149886, 0.8287811937137184, 0.8155556363877835, 0.7985976406114256, 0.7772125399725013], [0.9998770963044824, 0.9437234469399756, 0.9053711677233305, 0.8734362644125829, 0.852007963921677, 0.8315585013069123, 0.809338327119803, 0.793783111890158, 0.7774570667020625], [0.9998894566791583, 0.9409965552316286, 0.9029652775995638, 0.8740691657902634, 0.8497891651693077, 0.8308305642704782, 0.8101638026978626, 0.7935691129481134, 0.7762975018813641], [0.9998852823321072, 0.9396680649185929, 0.9015334074987851, 0.8708215586396981, 0.8479918940380894, 0.8263429886178709, 0.8095055298968566, 0.7912821038535439, 0.7736580571738173], [0.9998748003869217, 0.9412636163205615, 0.9006105998410944, 0.8723823362662628, 0.84853439926869, 0.825732712396809, 0.8088342730083622, 0.7903369920033346, 0.7754938026040957], [0.999882177483076, 0.9396291652097619, 0.8988655324862408, 0.8693771334855398, 0.8458381703552307, 0.8279005515102775, 0.8079062979180651, 0.7905040642325944, 0.7724713050937175], [0.9998640605935621, 0.939542431956946, 0.8987428556742023, 0.8703549629568803, 0.8483567385422006, 0.823939136177028, 0.805902484182028, 0.7879091539018169, 0.7696882818600085]]

# %%
# heatmap figure to replace the 3D surface
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data
x = K_list
y = alpha_list
X, Y = np.meshgrid(x, y)     # Create a grid of x and y values
g_fitness_across_alpha = np.array(g_fitness_across_alpha)
z = g_fitness_across_alpha
# Create the 2D color plot
plt.pcolormesh(x, y, z, cmap='jet')
plt.colorbar()  # Add a colorbar for reference

# Set the axis labels and title
plt.xlabel('K')
plt.xticks(x)
# plt.yticks(y)
plt.ylabel('$\\alpha$')
plt.title('Generalist Performance across $K$ and $\\alpha$')
plt.savefig(data_folder + r"\G_performance_colored.png", transparent=True, dpi=300)
# Display the plot
plt.show()

# %%
# heatmap figure to replace the 3D surface
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data
x = K_list
y = alpha_list
X, Y = np.meshgrid(x, y)     # Create a grid of x and y values
s_fitness_across_alpha = np.array(s_fitness_across_alpha)
z = s_fitness_across_alpha
# Create the 2D color plot
plt.pcolormesh(x, y, z, cmap='jet')
plt.colorbar()  # Add a colorbar for reference

# Set the axis labels and title
plt.xlabel('K')
plt.xticks(x)
# plt.yticks(y)
plt.ylabel('$\\alpha$')
plt.title('Specialist Performance across $K$ and $\\alpha$')
plt.savefig(data_folder + r"\S_performance_colored.png", transparent=True, dpi=300)
# Display the plot
plt.show()
