# %%
# heatmap figure to replace the 3D surface
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data
x = np.linspace(0, 10, 100)  # Values of x
y = np.linspace(0, 5, 50)    # Values of y
X, Y = np.meshgrid(x, y)     # Create a grid of x and y values
z = np.sin(X) + np.cos(Y)    # Compute the values of z based on x and y
# Create the 2D color plot
plt.pcolormesh(x, y, z, cmap='jet')
plt.colorbar()  # Add a colorbar for reference

# Set the axis labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('2D Color Plot Using Matplotlib')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
# Need a heatmap; X: K; Y: Alpha
# Together: Complexity in depth vs. Complexity in breadth
K_list = [0, 1, 2, 3, 4, 5, 6, 7, 8]
alpha_list = [0.30, 0.35, 0.40, 0.45, 0.50]
data_folder = r"E:\data\gst-0815-23\Pre-Test\TwoComplexity"
g_fitness_across_alpha, s_fitness_across_alpha = [], []
for alpha in alpha_list:
    g_file = data_folder + r"\g_performance_across_K_alpha_{0}".format(alpha)
    s_file = data_folder + r"\s_performance_across_K_alpha_{0}".format(alpha)
    
    with open(g_file, 'rb') as infile:
        g_fitness = pickle.load(infile)
    with open(s_file, 'rb') as infile:
        s_fitness = pickle.load(infile)
    g_fitness_across_alpha.append(g_fitness)
    s_fitness_across_alpha.append(s_fitness)

print(np.array(g_fitness_across_alpha).shape)
print(g_fitness_across_alpha)
print(s_fitness_across_alpha)
# Out:
# (5, 9)
# [[0.7820188039125301, 0.7687000614437342, 0.7505045550134599, 0.7360805879105449, 0.722834374367583, 0.7114291931293889, 0.7016148761865755, 0.6915439294743067, 0.6816555439357647], [0.77132108297592, 0.751348897976614, 0.7348993986337636, 0.7201128183689989, 0.7098530474955759, 0.7011608367384119, 0.6868815549867102, 0.6790943332013413, 0.6680542483057654], [0.7414338290897794, 0.7297312252505713, 0.7228654425210062, 0.7067052230639832, 0.6988068327648499, 0.6861594210466664, 0.6791164695226266, 0.6677009335696679, 0.6581819614924213], [0.7302532666005057, 0.7183294223005128, 0.7045422500461243, 0.6951911620676544, 0.6845328032158331, 0.6778158447058908, 0.668884421308992, 0.658812837942691, 0.6502923788200419], [0.7099371268451303, 0.7072297055341973, 0.6919986656082112, 0.6859245132172083, 0.6755040867857776, 0.6679330677851496, 0.6577779370309603, 0.6503006257354993, 0.641015042839793]]
# [[0.999871354449249, 0.9454412249999952, 0.9047194566691769, 0.876713533098982, 0.8518445207916946, 0.8317296092403853, 0.8123373664946699, 0.7937677469641078, 0.7801379665861562], [0.9998770963044824, 0.9437234469399756, 0.9053711677233305, 0.8734362644125829, 0.852007963921677, 0.8315585013069123, 0.809338327119803, 0.793783111890158, 0.7774570667020625], [0.9998852823321072, 0.9396680649185929, 0.9015334074987851, 0.8708215586396981, 0.8479918940380894, 0.8263429886178709, 0.8095055298968566, 0.7912821038535439, 0.7736580571738173], [0.999882177483076, 0.9396291652097619, 0.8988655324862408, 0.8693771334855398, 0.8458381703552307, 0.8279005515102775, 0.8079062979180651, 0.7905040642325944, 0.7724713050937175], [0.9998710508693428, 0.9390291117453452, 0.8983837209080349, 0.8686402303718026, 0.8462518425885266, 0.8248942330593555, 0.805485194762311, 0.7885937503469271, 0.7692289049816733]]

# %%
# heatmap figure to replace the 3D surface
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data
x = K_list
y = alpha_list
X, Y = np.meshgrid(x, y)     # Create a grid of x and y values
g_fitness_across_alpha = np.array(g_fitness_across_alpha)
z = g_fitness_across_alpha
# Create the 2D color plot
plt.pcolormesh(x, y, z, cmap='jet')
plt.colorbar()  # Add a colorbar for reference

# Set the axis labels and title
plt.xlabel('K')
plt.xticks(x)
plt.yticks(y)
plt.ylabel('$\\alpha$')
plt.title('Generalist Performance across $K$ and $\\alpha$')

# Display the plot
plt.show()

# %%
# heatmap figure to replace the 3D surface
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data
x = K_list
y = alpha_list
X, Y = np.meshgrid(x, y)     # Create a grid of x and y values
s_fitness_across_alpha = np.array(s_fitness_across_alpha)
z = s_fitness_across_alpha
# Create the 2D color plot
plt.pcolormesh(x, y, z, cmap='jet')
plt.colorbar()  # Add a colorbar for reference

# Set the axis labels and title
plt.xlabel('K')
plt.xticks(x)
plt.yticks(y)
plt.ylabel('$\\alpha$')
plt.title('Specialist Performance across $K$ and $\\alpha$')

# Display the plot
plt.show()
