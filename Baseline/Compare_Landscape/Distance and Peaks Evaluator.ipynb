# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
data_folder = r"E:\data\gst-0815-23\Pre-Test\Compare_Landscape_peaks"
alpha_list = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50]

first_peak_across_alpha, second_peak_across_alpha = [], []
first_distance_across_alpha, second_distance_across_alpha = [], []
for alpha in alpha_list:
    first_peak_file = data_folder + r"\first_local_peak_across_K_alpha_{0}".format(alpha)
    second_peak_file = data_folder + r"\second_local_peak_across_K_alpha_{0}".format(alpha)
    first_distance_file = data_folder + r"\first_distance_K_alpha_{0}".format(alpha)
    second_distance_file = data_folder + r"\second_distance_K_alpha_{0}".format(alpha)
    with open(first_peak_file, 'rb') as infile:
        first_peak = pickle.load(infile)
    with open(second_peak_file, 'rb') as infile:
        second_peak = pickle.load(infile)

    with open(first_distance_file, 'rb') as infile:
        first_distance = pickle.load(infile)
    with open(second_distance_file, 'rb') as infile:
        second_distance = pickle.load(infile)

    first_peak_across_alpha.append(first_peak)
    second_peak_across_alpha.append(second_peak)
    first_distance_across_alpha.append(first_distance)
    second_distance_across_alpha.append(second_distance)

# %%
print(np.array(first_distance_across_alpha).shape)
print(np.array(first_distance_across_alpha[1]).shape)
# Out:
# (10, 9)
# (9,)

# %%
# First Peaks
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
# Plot the data with solid line and downward triangle markers
ax.plot(range(9), first_peak_across_alpha[0], marker='v', linestyle='-', color='k', label='$\\alpha=0.05$')
ax.plot(range(9), first_peak_across_alpha[1], marker='s', linestyle='-', color='k', label='$\\alpha=0.10$')
ax.plot(range(9), first_peak_across_alpha[2], marker='o', linestyle='-', color='k', label='$\\alpha=0.15$')
plt.title("Coarse Level Peaks")
# plt.savefig(data_folder + r"\first_peak.png", transparent=True, dpi=300)
plt.show()

# %%
# First Peaks -- professional
import matplotlib.pyplot as plt
import numpy as np

# Generating some sample data
absolute_counts = first_peak_across_alpha[0]

# Calculating proportions based on the total count
total_count = 2 ** 9
proportion_list = [each / total_count for each in absolute_counts]

fig, ax1 = plt.subplots()

# Plotting the absolute counts on the left y-axis
color = nature_orange
ax1.set_xlabel('Parameter K')
ax1.set_ylabel('Absolute Count', color=color)
ax1.plot(range(9), absolute_counts, marker='v', linestyle='-', color=nature_orange, label='Local Peaks')
# ax1.tick_params(axis='y', labelcolor=color)

# Creating the right y-axis for proportions
ax2 = ax1.twinx()
color = nature_blue
# ax2.set_ylabel('Proportion', color=color)
# ax2.plot(range(9), proportion_list, linestyle='-', color=nature_orange, label='Local Peaks')
# ax2.tick_params(axis='y', labelcolor=color)

ax1.set_xlabel("$K$", fontweight='bold', fontsize = 12)
ax1.set_ylabel("Number of Local Peaks", fontweight='bold', color="black", fontsize=12)
ax2.set_ylabel("Proportion of Local Peaks", fontweight='bold', color="black", fontsize=12)

# ax2.spines['left'].set_color(nature_orange) # left y-axis
# ax1.yaxis.label.set_color(nature_orange) # left y-axis labels
# ax1.tick_params(axis='y', colors=nature_orange) # left y-axis params

# ax2.spines['right'].set_color(nature_blue) # right y-axis
# ax2.yaxis.label.set_color(nature_blue)  # right y-axis labels
# ax2.tick_params(axis='y', colors=nature_blue) # right y-axis params

ax1.spines["left"].set_linewidth(1.5)
ax1.spines["right"].set_linewidth(1.5)
ax1.spines["top"].set_linewidth(1.5)
ax1.spines["bottom"].set_linewidth(1.5)
ax2.spines["left"].set_linewidth(1.5)
ax2.spines["right"].set_linewidth(1.5)
ax2.spines["top"].set_linewidth(1.5)
ax2.spines["bottom"].set_linewidth(1.5)

fig.tight_layout()
plt.title('Local Peaks on Coarse Landscapes')
plt.savefig(data_folder + r"\first_peak.png", transparent=True, dpi=300, bbox_inches='tight')
plt.show()

# %%
# Second Peaks
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
# Plot the data with solid line and downward triangle markers
ax.plot(range(9), second_peak_across_alpha[0], marker='v', linestyle='-', color='k', label='$\\alpha=0.05$')
ax.plot(range(9), second_peak_across_alpha[1], marker='s', linestyle='-', color='k', label='$\\alpha=0.10$')
ax.plot(range(9), second_peak_across_alpha[2], marker='o', linestyle='-', color='k', label='$\\alpha=0.15$')
plt.title("Local Peaks on Fine Landscape")
ax.legend(frameon=False, ncol=1, fontsize=12, prop=legend_properties)
# plt.savefig(data_folder + r"\second_peak.png", transparent=True, dpi=300)
plt.show()

# %%
# Second Peaks -- professional
import matplotlib.pyplot as plt
# alpha_list = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50]
total_count = 4 ** 9
# Generating some sample data
absolute_counts_1 = second_peak_across_alpha[0]
proportion_list_1 = [each / total_count for each in absolute_counts_1]

absolute_counts_2 = second_peak_across_alpha[2]
proportion_list_2 = [each / total_count for each in absolute_counts_2]

absolute_counts_3 = second_peak_across_alpha[4]
proportion_list_3 = [each / total_count for each in absolute_counts_3]

fig, ax1 = plt.subplots()

# Plotting the absolute counts on the left y-axis
# color = nature_orange
line_1 = ax1.plot(range(9), absolute_counts_1, marker='o', linestyle='-', color=nature_blue, label='$\\alpha=0.05$')
line_2 = ax1.plot(range(9), absolute_counts_2, marker='s', linestyle='-', color=nature_green, label='$\\alpha=0.15$')
line_3 = ax1.plot(range(9), absolute_counts_3, marker='v', linestyle='-', color=nature_orange, label='$\\alpha=0.25$')
# ax1.tick_params(axis='y', labelcolor=color)

# Creating the right y-axis for proportions
ax2 = ax1.twinx()
# color = nature_blue
# ax2.set_ylabel('Proportion', color=color)
# line_4 = ax2.plot(range(9), proportion_list_1, linestyle='-', color='k', label='Local Peaks')
# line_5 = ax2.plot(range(9), proportion_list_2, linestyle='-', color='k', label='Local Peaks')
# line_6 = ax2.plot(range(9), proportion_list_3, linestyle='-', color='k', label='Local Peaks')
# ax2.tick_params(axis='y', labelcolor=color)

ax1.set_xlabel("$K$", fontweight='bold', fontsize = 12)
ax1.set_ylabel("Number of Local Peaks", fontweight='bold', color="black", fontsize=12)
ax2.set_ylabel("Proportion of Local Peaks", fontweight='bold', color="black", fontsize=12)

# ax2.spines['left'].set_color(nature_orange) # left y-axis
# ax1.yaxis.label.set_color(nature_orange) # left y-axis labels
# ax1.tick_params(axis='y', colors=nature_orange) # left y-axis params

# ax2.spines['right'].set_color(nature_blue) # right y-axis
# ax2.yaxis.label.set_color(nature_blue)  # right y-axis labels
# ax2.tick_params(axis='y', colors=nature_blue) # right y-axis params

ax1.spines["left"].set_linewidth(1.5)
ax1.spines["right"].set_linewidth(1.5)
ax1.spines["top"].set_linewidth(1.5)
ax1.spines["bottom"].set_linewidth(1.5)
ax2.spines["left"].set_linewidth(1.5)
ax2.spines["right"].set_linewidth(1.5)
ax2.spines["top"].set_linewidth(1.5)
ax2.spines["bottom"].set_linewidth(1.5)

lines_1 = line_1 + line_2 + line_3
labs_1 = [l.get_label() for l in lines_1]
ax1.legend(lines_1, labs_1, frameon=False, fontsize=12,  ncol=3, prop=legend_properties)

fig.tight_layout()
plt.title('Local Peaks on Fine Landscapes')
plt.savefig(data_folder + r"\second_peak.png", transparent=True, dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
# alpha_list = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50]
fig, ax = plt.subplots()
# Plot the data with solid line and downward triangle markers
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
ax.plot(range(9), first_distance_across_alpha[0], marker='s', linestyle='-', color=nature_blue, label='coarse')
# ax.plot(range(9), first_distance_across_alpha[1], marker='v', linestyle='--', color='k', label='coarse') # no difference
ax.plot(range(9), second_distance_across_alpha[0], linestyle=':', color=nature_orange, label='fine $\\alpha=0.05$')
ax.plot(range(9), second_distance_across_alpha[2], linestyle='--', color=nature_orange, label='fine $\\alpha=0.15$')
ax.plot(range(9), second_distance_across_alpha[4], linestyle='-', color=nature_orange, label='fine $\\alpha=0.25$')
# plt.title("Average Distance")
ax.set_xlabel("$K$", fontweight='bold', fontsize = 12)
ax.set_ylabel("Neighborhood Distance", fontweight='bold', fontsize = 12)
plt.legend(frameon=False, fontsize=12)
plt.savefig(data_folder + r"\distance.png", transparent=True, dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating some sample data
K_values = np.arange(1, 11)
absolute_counts = np.random.randint(50, 200, size=10)  # Sample absolute counts

# Calculating proportions based on the total count
total_count = absolute_counts.sum()
proportions = absolute_counts / total_count

fig, ax1 = plt.subplots()

# Plotting the absolute counts on the left y-axis
color = 'tab:blue'
ax1.set_xlabel('Parameter K')
ax1.set_ylabel('Absolute Count', color=color)
ax1.plot(K_values, absolute_counts, color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Creating the right y-axis for proportions
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Proportion', color=color)
ax2.plot(K_values, proportions, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()
plt.title('Absolute Count and Proportion with respect to Parameter K')
plt.show()
