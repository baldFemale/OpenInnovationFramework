# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
data_folder = r"E:\data\gst-1112\Coupling\gs"

g_performance_0_file = data_folder + r"\g_performance_across_K_0"
g_performance_1_file = data_folder + r"\g_performance_across_K_1"
g_performance_2_file = data_folder + r"\g_performance_across_K_2"
g_performance_3_file = data_folder + r"\g_performance_across_K_3"
with open(g_performance_0_file, 'rb') as infile:
    g_performance_0 = pickle.load(infile)
with open(g_performance_1_file, 'rb') as infile:
    g_performance_1 = pickle.load(infile)
with open(g_performance_2_file, 'rb') as infile:
    g_performance_2 = pickle.load(infile)
with open(g_performance_3_file, 'rb') as infile:
    g_performance_3 = pickle.load(infile)

s_performance_0_file = data_folder + r"\s_performance_across_K_0"
s_performance_1_file = data_folder + r"\s_performance_across_K_1"
s_performance_2_file = data_folder + r"\s_performance_across_K_2"
s_performance_3_file = data_folder + r"\s_performance_across_K_3"
with open(s_performance_0_file, 'rb') as infile:
    s_performance_0 = pickle.load(infile)
with open(s_performance_1_file, 'rb') as infile:
    s_performance_1 = pickle.load(infile)
with open(s_performance_2_file, 'rb') as infile:
    s_performance_2 = pickle.load(infile)
with open(s_performance_3_file, 'rb') as infile:
    s_performance_3 = pickle.load(infile)

# %%
print(np.array(g_performance_0).shape)
print(np.array(g_performance_3).shape)
print(g_performance_0)
# Out:
# (36,)
# (9,)
# [0.7254909446960142, 0.6651343917990797, 0.637045609956443, 0.6206017935827683, 0.6093596197178313, 0.5989713954342643, 0.5906541901516433, 0.5833265591826595, 0.5782785213327046, 0.7223667184469348, 0.6689331320108782, 0.6375243984032197, 0.6206123702164607, 0.6083754065092586, 0.5980975568615855, 0.5905700429809309, 0.5843279488509763, 0.5780383053962134, 0.7219650058711108, 0.6654408105396118, 0.6358106995475212, 0.6202556437564817, 0.607761374800763, 0.5980855766931434, 0.5906629179994953, 0.583847729068644, 0.578049061562324, 0.720788348243122, 0.6668115931546723, 0.6372753470150692, 0.6206988785153792, 0.6092675171028101, 0.5977819375598789, 0.5902120137787074, 0.5826813558895947, 0.5786702005185631]

# %%
# Performance
x = [0, 1, 2, 3, 4, 5, 6, 7, 8]
plt.plot(x, g_performance_0[27:36], "r-", label="")
plt.plot(x, g_performance_1[18:27], "b-", label="S")
plt.plot(x, g_performance_2[9:18], "g-", label="T")
plt.plot(x, g_performance_3, "k-", label="T")
# plt.title('Diversity Decrease')
plt.xlabel('K', fontweight='bold', fontsize=10)
plt.ylabel('Performance', fontweight='bold', fontsize=10)
plt.xticks(x)
plt.legend(frameon=False, ncol=3, fontsize=10)
plt.savefig(data_folder + r"\GST_performance_K.png", transparent=False, dpi=200)
plt.show()
plt.clf()

# %%
g_original_performance_file = data_folder + r"\g_original_performance_across_K"
s_original_performance_file = data_folder + r"\s_original_performance_across_K"
t_original_performance_file = data_folder + r"\t_original_performance_across_K"
with open(g_original_performance_file, 'rb') as infile:
    g_original_performance = pickle.load(infile)
with open(s_original_performance_file, 'rb') as infile:
    s_original_performance = pickle.load(infile)
with open(t_original_performance_file, 'rb') as infile:
    t_original_performance = pickle.load(infile)
print(np.array(g_original_performance).shape)
print(np.array(g_original_performance[0]).shape)
# Out:
# (9, 50000)
# (50000,)

# %%
# Performance across iteration
agent_num = 100
# G
for K, performance_list_K in enumerate(t_original_performance):
    temp_curve = []
    for index in range(len(performance_list_K)):
        if (index + 1) % agent_num == 0:
            temp_curve.append(sum(performance_list_K[0:index]) / len(performance_list_K[0:index]))
    plt.plot(range(len(temp_curve)), temp_curve, label="K={0}".format(K))
plt.xlabel('Iterations', fontweight='bold', fontsize=10)
plt.ylabel('Performance', fontweight='bold', fontsize=10)
# plt.xticks(x)
plt.legend(frameon=False, ncol=3, fontsize=10)
plt.savefig(data_folder + r"\T_original_performance.png", transparent=False, dpi=200)
plt.show()
plt.clf()

# %%
# Potential Performamce
g_potential_file = data_folder + r"\g_potential_across_K"
s_potential_file = data_folder + r"\s_potential_across_K"
t_potential_file = data_folder + r"\t_potential_across_K"
with open(g_potential_file, 'rb') as infile:
    g_potential = pickle.load(infile)
with open(s_potential_file, 'rb') as infile:
    s_potential = pickle.load(infile)
with open(t_potential_file, 'rb') as infile:
    t_potential = pickle.load(infile)
x = [0, 1, 2, 3, 4, 5, 6, 7, 8]
plt.plot(x, g_potential, "r-", label="G")
plt.plot(x, s_potential, "b-", label="S")
plt.plot(x, t_potential, "g-", label="T")
# plt.title('Diversity Decrease')
plt.xlabel('K', fontweight='bold', fontsize=10)
plt.ylabel('Potential', fontweight='bold', fontsize=10)
plt.xticks(x)
plt.legend(frameon=False, ncol=3, fontsize=10)
plt.savefig(data_folder + r"\GST_potential_K.png", transparent=False, dpi=200)
plt.show()
plt.clf()
