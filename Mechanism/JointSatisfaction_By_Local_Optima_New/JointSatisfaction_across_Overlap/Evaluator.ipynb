# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
data_folder = r"E:\data\gst-0815-23\Mechanism_6_use_local_optima\JointSatisfaction_across_Overlap_1"
overlap_list = [1, 2, 3]
gg_satisfaction_across_K_overlap, gs_satisfaction_across_K_overlap, ss_satisfaction_across_K_overlap, sg_satisfaction_across_K_overlap = [], [], [], []
for overlap in overlap_list:
    gg_satisfaction_file = data_folder + r"\gg_joint_satisfaction_across_K_overlap_{0}".format(overlap)
    gs_satisfaction_file = data_folder + r"\gs_joint_satisfaction_across_K_overlap_{0}".format(overlap)
    ss_satisfaction_file = data_folder + r"\ss_joint_satisfaction_across_K_overlap_{0}".format(overlap)
    sg_satisfaction_file = data_folder + r"\sg_joint_satisfaction_across_K_overlap_{0}".format(overlap)
    
    with open(gg_satisfaction_file, 'rb') as infile:
        gg_satisfaction = pickle.load(infile)
    with open(gs_satisfaction_file, 'rb') as infile:
        gs_satisfaction = pickle.load(infile)
    with open(ss_satisfaction_file, 'rb') as infile:
        ss_satisfaction = pickle.load(infile)
    with open(sg_satisfaction_file, 'rb') as infile:
        sg_satisfaction = pickle.load(infile)
        
    gg_satisfaction_across_K_overlap.append(gg_satisfaction)
    gs_satisfaction_across_K_overlap.append(gs_satisfaction)
    ss_satisfaction_across_K_overlap.append(ss_satisfaction)
    sg_satisfaction_across_K_overlap.append(sg_satisfaction)
    print(sg_satisfaction)
# print(np.array(ss_satisfaction_across_K_alpha).shape)
# print(gs_satisfaction_across_K_alpha)
# print(sg_satisfaction_across_K_alpha)
# Out:
# [0.8900715999999999, 0.5678913399999999, 0.4182022799999999, 0.33725552000000014, 0.2947853800000004, 0.27202988000000006, 0.26087178, 0.25852012000000013, 0.26206428000000015]
# [0.8200716800000001, 0.5055631399999999, 0.3651643599999999, 0.29382965999999977, 0.25899401999999994, 0.24270055999999993, 0.23684977999999998, 0.23889569999999982, 0.24505395999999982]
# [0.7863192199999998, 0.47285130000000003, 0.3449774200000001, 0.27533006, 0.24328578, 0.2303742, 0.22745731999999994, 0.23098555999999962, 0.23910897999999992]

# %%
# GG Overlap
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gg_satisfaction_across_K_overlap[0], "-", label="GG Overlap=1", color=nature_blue)
plt.plot(x, gg_satisfaction_across_K_overlap[1], "-", label="GG Overlap=2", color=nature_green)
plt.plot(x, gg_satisfaction_across_K_overlap[2], "-", label="GG Overlap=3", color=nature_orange)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.title("SS")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_SS.png", transparent=True, dpi=300)
plt.show()

# %%
# SG Overlap
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, sg_satisfaction_across_K_overlap[0], "-", label="SG Overlap=1", color=nature_blue)
plt.plot(x, sg_satisfaction_across_K_overlap[1], "-", label="SG Overlap=2", color=nature_green)
plt.plot(x, sg_satisfaction_across_K_overlap[2], "-", label="SG Overlap=3", color=nature_orange)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.title("SS")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_SG.png", transparent=True, dpi=300)
plt.show()

# %%
# SS Overlap
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, ss_satisfaction_across_K_overlap[0], "-", label="SS Overlap=1", color=nature_blue)
plt.plot(x, ss_satisfaction_across_K_overlap[1], "-", label="SS Overlap=2", color=nature_green)
plt.plot(x, ss_satisfaction_across_K_overlap[2], "-", label="SS Overlap=3", color=nature_orange)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.title("SS")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_SS.png", transparent=True, dpi=300)
plt.show()

# %%
# GS Overlap
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gs_satisfaction_across_K_overlap[0], "-", label="GS Overlap=1", color=nature_blue)
plt.plot(x, gs_satisfaction_across_K_overlap[1], "-", label="GS Overlap=2", color=nature_green)
plt.plot(x, gs_satisfaction_across_K_overlap[2], "-", label="GS Overlap=3", color=nature_orange)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.title("SS")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_GS.png", transparent=True, dpi=300)
plt.show()

# %%
# Integrate S
S_satisfaction_across_K_overlap = []
for ss_across_K, gs_across_K in zip(ss_satisfaction_across_K_overlap, gs_satisfaction_across_K_overlap):
    new_s_list = []
    for ss, gs in zip(ss_across_K, gs_across_K):
        new_s = 0.5 * (ss + gs)
        new_s_list.append(new_s)
    S_satisfaction_across_K_overlap.append(new_s_list)
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, S_satisfaction_across_K_overlap[0], "-", label="S Overlap=1", color=nature_blue)
# plt.plot(x, S_satisfaction_across_K_overlap[1], "-", label="S Overlap=2", color=nature_green)
plt.plot(x, S_satisfaction_across_K_overlap[2], "-", label="S Overlap=3", color=nature_orange)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
# plt.title("SS")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_S.png", transparent=True, dpi=300)
plt.show()

# %%
# Integrate G
G_satisfaction_across_K_overlap = []
for gg_across_K, sg_across_K in zip(gg_satisfaction_across_K_overlap, sg_satisfaction_across_K_overlap):
    new_g_list = []
    for gg, sg in zip(gg_across_K, sg_across_K):
        new_g = 0.5 * (gg + sg)
        new_g_list.append(new_g)
    G_satisfaction_across_K_overlap.append(new_g_list)
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, G_satisfaction_across_K_overlap[0], "-", label="G Overlap=1", color=nature_blue)
# plt.plot(x, G_satisfaction_across_K_overlap[1], "-", label="G Overlap=2", color=nature_green)
plt.plot(x, G_satisfaction_across_K_overlap[2], "-", label="G Overlap=3", color=nature_orange)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_G.png", transparent=True, dpi=300)
plt.show()

# %%
# Integrate G and S
G_satisfaction_across_K_overlap = []
for gg_across_K, sg_across_K in zip(gg_satisfaction_across_K_overlap, sg_satisfaction_across_K_overlap):
    new_g_list = []
    for gg, sg in zip(gg_across_K, sg_across_K):
        new_g = 0.5 * (gg + sg)
        new_g_list.append(new_g)
    G_satisfaction_across_K_overlap.append(new_g_list)

S_satisfaction_across_K_overlap = []
for ss_across_K, gs_across_K in zip(ss_satisfaction_across_K_overlap, gs_satisfaction_across_K_overlap):
    new_s_list = []
    for ss, gs in zip(ss_across_K, gs_across_K):
        new_s = 0.5 * (ss + gs)
        new_s_list.append(new_s)
    S_satisfaction_across_K_overlap.append(new_s_list)
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, G_satisfaction_across_K_overlap[0], "-", label="G Overlap=1", color=nature_blue)
# plt.plot(x, G_satisfaction_across_K_overlap[1], "-", label="G Overlap=2", color=nature_green)
plt.plot(x, G_satisfaction_across_K_overlap[2], "-", label="G Overlap=3", color=nature_orange)

plt.plot(x, S_satisfaction_across_K_overlap[0], "--", label="S Overlap=1", color=nature_blue)
# plt.plot(x, S_satisfaction_across_K_overlap[1], "--", label="S Overlap=2", color=nature_green)
plt.plot(x, S_satisfaction_across_K_overlap[2], "--", label="S Overlap=3", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap.png", transparent=True, dpi=300)
plt.show()
