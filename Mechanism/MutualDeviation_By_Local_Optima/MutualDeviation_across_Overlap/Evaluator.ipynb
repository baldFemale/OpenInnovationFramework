# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
data_folder = r"F:\data\gst-0815-23\Mechanism_6_use_local_optima\MutualDeviation_across_Overlap"
overlap_list = [1, 2, 3]
gg_deviation_across_K_overlap, gs_deviation_across_K_overlap, ss_deviation_across_K_overlap, sg_deviation_across_K_overlap = [], [], [], []
for overlap in overlap_list:
    gg_deviation_file = data_folder + r"\gg_mutual_deviation_across_K_overlap_{0}".format(overlap)
    gs_deviation_file = data_folder + r"\gs_mutual_deviation_across_K_overlap_{0}".format(overlap)
    ss_deviation_file = data_folder + r"\ss_mutual_deviation_across_K_overlap_{0}".format(overlap)
    sg_deviation_file = data_folder + r"\sg_mutual_deviation_across_K_overlap_{0}".format(overlap)
    
    with open(gg_deviation_file, 'rb') as infile:
        gg_deviation = pickle.load(infile)
    with open(gs_deviation_file, 'rb') as infile:
        gs_deviation = pickle.load(infile)
    with open(ss_deviation_file, 'rb') as infile:
        ss_deviation = pickle.load(infile)
    with open(sg_deviation_file, 'rb') as infile:
        sg_deviation = pickle.load(infile)
        
    gg_deviation_across_K_overlap.append(gg_deviation)
    gs_deviation_across_K_overlap.append(gs_deviation)
    ss_deviation_across_K_overlap.append(ss_deviation)
    sg_deviation_across_K_overlap.append(sg_deviation)
    print(sg_deviation)
# print(np.array(ss_satisfaction_across_K_alpha).shape)
# print(gs_satisfaction_across_K_alpha)
# print(sg_satisfaction_across_K_alpha)
# Out:
# [0.18751799999999996, 0.4659451875000001, 0.6179235000000002, 0.6935299374999998, 0.7338112500000004, 0.7525114375000003, 0.7590796875000001, 0.7587698125000004, 0.7526552499999997]
# [0.24650343750000003, 0.49439856249999986, 0.6286265625, 0.7039261875000001, 0.7395972500000002, 0.7583768124999999, 0.7642038749999999, 0.7619718750000001, 0.7549920625]
# [0.2520759375, 0.5009384374999999, 0.641580875, 0.7072614374999998, 0.7423679375000001, 0.7582669375000002, 0.762952625, 0.7602441874999997, 0.7528594999999997]

# %%
# Mutual Deviation
x = range(1, 9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gg_deviation_across_K_overlap[0][1:], "-", label="GG Overlap=1", color=nature_blue)
plt.plot(x, gg_deviation_across_K_overlap[1][1:], "-", label="GG Overlap=2", color=nature_green)
plt.plot(x, gg_deviation_across_K_overlap[2][1:], "-", label="GG Overlap=3", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap_GG.png", transparent=True, dpi=300)
plt.show()

# %%
# Mutual Deviation
x = range(1, 9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, sg_deviation_across_K_overlap[0][1:], "-", label="SG Overlap=1", color=nature_blue)
plt.plot(x, sg_deviation_across_K_overlap[1][1:], "-", label="SG Overlap=2", color=nature_green)
plt.plot(x, sg_deviation_across_K_overlap[2][1:], "-", label="SG Overlap=3", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap_SG.png", transparent=True, dpi=300)
plt.show()

# %%
# Mutual Deviation
x = range(1, 9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, ss_deviation_across_K_overlap[0][1:], "-", label="SS Overlap=1", color=nature_blue)
plt.plot(x, ss_deviation_across_K_overlap[1][1:], "-", label="SS Overlap=2", color=nature_green)
plt.plot(x, ss_deviation_across_K_overlap[2][1:], "-", label="SS Overlap=3", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap_SS.png", transparent=True, dpi=300)
plt.show()

# %%
# Mutual Deviation
x = range(1, 9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gs_deviation_across_K_overlap[0][1:], "-", label="GS Overlap=1", color=nature_blue)
plt.plot(x, gs_deviation_across_K_overlap[1][1:], "-", label="GS Overlap=2", color=nature_green)
plt.plot(x, gs_deviation_across_K_overlap[2][1:], "-", label="GS Overlap=3", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation',  fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap_GS.png", transparent=True, dpi=300)
plt.show()

# %%
# Integrate G and S
G_deviation_across_K_overlap = []
for gg_across_K, sg_across_K in zip(gg_deviation_across_K_overlap, sg_deviation_across_K_overlap):
    new_g_list = []
    for gg, sg in zip(gg_across_K, sg_across_K):
        new_g = 0.5 * (gg + sg)
        new_g_list.append(new_g)
    G_deviation_across_K_overlap.append(new_g_list)

S_deviation_across_K_overlap = []
for ss_across_K, gs_across_K in zip(ss_deviation_across_K_overlap, gs_deviation_across_K_overlap):
    new_s_list = []
    for ss, gs in zip(ss_across_K, gs_across_K):
        new_s = 0.5 * (ss + gs)
        new_s_list.append(new_s)
    S_deviation_across_K_overlap.append(new_s_list)
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, G_deviation_across_K_overlap[0], marker='o', linestyle='-', label="G Low Overlap", color=nature_blue)
plt.plot(x, G_deviation_across_K_overlap[1], marker='s', linestyle='-', label="G Medium Overlap", color=nature_blue)
plt.plot(x, G_deviation_across_K_overlap[2], marker='v', linestyle='-', label="G High Overlap", color=nature_blue)

plt.plot(x, S_deviation_across_K_overlap[0], marker='o', linestyle='-', label="S Low Overlap", color=nature_orange)
plt.plot(x, S_deviation_across_K_overlap[1], marker='s', linestyle='-', label="S Medium Overlap", color=nature_orange)
plt.plot(x, S_deviation_across_K_overlap[2], marker='v', linestyle='-', label="S High Overlap", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap.png", transparent=True, dpi=300)
plt.show()
