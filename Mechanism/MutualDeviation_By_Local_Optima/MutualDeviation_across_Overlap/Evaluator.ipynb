# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
data_folder = r"E:\data\gst-0815-23\Mechanism_6_use_local_optima\MutualDeviation_across_Overlap_2"
overlap_list = [1, 2, 3]
gg_overlap_list = [3, 4, 5, 6]
gg_deviation_across_K_overlap, gs_deviation_across_K_overlap, ss_deviation_across_K_overlap, sg_deviation_across_K_overlap = [], [], [], []
for overlap in overlap_list:
    gs_deviation_file = data_folder + r"\gs_mutual_deviation_across_K_overlap_{0}".format(overlap)
    ss_deviation_file = data_folder + r"\ss_mutual_deviation_across_K_overlap_{0}".format(overlap)
    sg_deviation_file = data_folder + r"\sg_mutual_deviation_across_K_overlap_{0}".format(overlap)
    with open(gs_deviation_file, 'rb') as infile:
        gs_deviation = pickle.load(infile)
    with open(ss_deviation_file, 'rb') as infile:
        ss_deviation = pickle.load(infile)
    with open(sg_deviation_file, 'rb') as infile:
        sg_deviation = pickle.load(infile)
    gs_deviation_across_K_overlap.append(gs_deviation)
    ss_deviation_across_K_overlap.append(ss_deviation)
    sg_deviation_across_K_overlap.append(sg_deviation)

for gg_overlap in gg_overlap_list:
    gg_deviation_file = data_folder + r"\gg_mutual_deviation_across_K_overlap_{0}".format(gg_overlap)
    with open(gg_deviation_file, 'rb') as infile:
        gg_deviation = pickle.load(infile)
    gg_deviation_across_K_overlap.append(gg_deviation)

print(gg_deviation_across_K_overlap)
# print(np.array(ss_satisfaction_across_K_alpha).shape)
# print(gs_satisfaction_across_K_alpha)
# print(sg_satisfaction_across_K_alpha)
# Out:
# [[0.0, 0.38357050000000004, 0.5649446250000001, 0.6401177500000002, 0.683651625, 0.7117715625, 0.7269304999999998, 0.7303993125000001, 0.7293581250000001], [0.0, 0.378542125, 0.5437518749999997, 0.6316918749999999, 0.6799504375000001, 0.7082536874999998, 0.7256238125000002, 0.7309466249999998, 0.7300547499999998], [0.0, 0.37714337500000006, 0.53700375, 0.6293690624999999, 0.6716969374999998, 0.7068193750000001, 0.7230941250000003, 0.7317762499999999, 0.73232], [0.0, 0.32986693749999996, 0.52839125, 0.6287335625000002, 0.6891678125, 0.7221335000000001, 0.7420203124999998, 0.7493249999999998, 0.7508718124999999]]

# %%
# Mutual Deviation
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gg_deviation_across_K_overlap[0], "-", label="GG Overlap=3", color=nature_blue)
plt.plot(x, gg_deviation_across_K_overlap[1], "-", label="GG Overlap=4", color=nature_green)
plt.plot(x, gg_deviation_across_K_overlap[2], "-", label="GG Overlap=5", color=nature_orange)
plt.plot(x, gg_deviation_across_K_overlap[3], "-", label="GG Overlap=6", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap_GG.png", transparent=True, dpi=300)
plt.show()

# %%
# Mutual Deviation
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, sg_deviation_across_K_overlap[0], "-", label="SG Overlap=1", color=nature_blue)
plt.plot(x, sg_deviation_across_K_overlap[1], "-", label="SG Overlap=2", color=nature_green)
plt.plot(x, sg_deviation_across_K_overlap[2], "-", label="SG Overlap=3", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap_SG.png", transparent=True, dpi=300)
plt.show()

# %%
# Mutual Deviation
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, ss_deviation_across_K_overlap[0], "-", label="SS Overlap=1", color=nature_blue)
plt.plot(x, ss_deviation_across_K_overlap[1], "-", label="SS Overlap=2", color=nature_green)
plt.plot(x, ss_deviation_across_K_overlap[2], "-", label="SS Overlap=3", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap_SS.png", transparent=True, dpi=300)
plt.show()

# %%
# Mutual Deviation
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gs_deviation_across_K_overlap[0], "-", label="GS Overlap=1", color=nature_blue)
plt.plot(x, gs_deviation_across_K_overlap[1], "-", label="GS Overlap=2", color=nature_green)
plt.plot(x, gs_deviation_across_K_overlap[2], "-", label="GS Overlap=3", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation',  fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap_GS.png", transparent=True, dpi=300)
plt.show()

# %%
# Integrate G and S
G_deviation_across_K_overlap = []
for gg_across_K, sg_across_K in zip(gg_deviation_across_K_overlap, sg_deviation_across_K_overlap):
    new_g_list = []
    for gg, sg in zip(gg_across_K, sg_across_K):
        new_g = 0.5 * (gg + sg)
        new_g_list.append(new_g)
    G_deviation_across_K_overlap.append(new_g_list)

S_deviation_across_K_overlap = []
for ss_across_K, gs_across_K in zip(ss_deviation_across_K_overlap, gs_deviation_across_K_overlap):
    new_s_list = []
    for ss, gs in zip(ss_across_K, gs_across_K):
        new_s = 0.5 * (ss + gs)
        new_s_list.append(new_s)
    S_deviation_across_K_overlap.append(new_s_list)
x = range(1, 9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
# plt.plot(x, G_deviation_across_K_overlap[0], marker='o', linestyle='-', label="G Low Overlap", color=nature_blue)
# plt.plot(x, G_deviation_across_K_overlap[1], marker='s', linestyle='-', label="G Medium Overlap", color=nature_blue)
# plt.plot(x, G_deviation_across_K_overlap[2], marker='v', linestyle='-', label="G High Overlap", color=nature_blue)

plt.plot(x, G_deviation_across_K_overlap[0][1:], marker='o', linestyle='-', label="G Low Overlap", color=nature_blue)
plt.plot(x, G_deviation_across_K_overlap[1][1:], marker='s', linestyle='-', label="G Medium Overlap", color=nature_blue)
plt.plot(x, G_deviation_across_K_overlap[2][1:], marker='v', linestyle='-', label="G High Overlap", color=nature_blue)

plt.plot(x, S_deviation_across_K_overlap[0][1:], marker='o', linestyle='-', label="S Low Overlap", color=nature_orange)
plt.plot(x, S_deviation_across_K_overlap[1][1:], marker='s', linestyle='-', label="S Medium Overlap", color=nature_orange)
plt.plot(x, S_deviation_across_K_overlap[2][1:], marker='v', linestyle='-', label="S High Overlap", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Mutual Deviation', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.title("(h) Knowledge Overlap")
plt.legend(frameon=False, fontsize=12)
plt.savefig(data_folder + r"\Mutual_Deviation_across_Overlap.png", transparent=True, dpi=300)
plt.show()
