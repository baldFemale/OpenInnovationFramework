# %%
import matplotlib.pyplot as plt
# plt.interactive(False)
from scipy.stats import gaussian_kde
from scipy.special import kl_div
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
data_folder = r"E:\data\gst-0512\Independent_partial"
g_ave_performance_file = data_folder + r"\g_ave_performance_across_K"
g_max_performance_file = data_folder + r"\g_max_performance_across_K"
g_min_performance_file = data_folder + r"\g_min_performance_across_K"
g_cog_performance_file = data_folder + r"\g_cog_performance_across_K"
g_variance_file = data_folder + r"\g_variance_across_K"
g_cog_variance_file = data_folder + r"\g_cog_variance_across_K"
g_first_quantile_file = data_folder + r"\g_first_quantile_across_K"
g_last_quantile_file = data_folder + r"\g_last_quantile_across_K"

s_ave_performance_file = data_folder + r"\s_ave_performance_across_K"
s_max_performance_file = data_folder + r"\s_max_performance_across_K"
s_min_performance_file = data_folder + r"\s_min_performance_across_K"
s_cog_performance_file = data_folder + r"\s_cog_performance_across_K"
s_variance_file = data_folder + r"\s_variance_across_K"
s_cog_variance_file = data_folder + r"\s_cog_variance_across_K"
s_first_quantile_file = data_folder + r"\s_first_quantile_across_K"
s_last_quantile_file = data_folder + r"\s_last_quantile_across_K"

with open(g_ave_performance_file, 'rb') as infile:
    g_ave = pickle.load(infile)
with open(g_max_performance_file, 'rb') as infile:
    g_max = pickle.load(infile)
with open(g_min_performance_file, 'rb') as infile:
    g_min = pickle.load(infile)
with open(g_cog_performance_file, 'rb') as infile:
    g_cog = pickle.load(infile)
with open(g_variance_file, 'rb') as infile:
    g_var = pickle.load(infile)
with open(g_cog_variance_file, 'rb') as infile:
    g_cog_var = pickle.load(infile)
with open(g_first_quantile_file, 'rb') as infile:
    g_first = pickle.load(infile)
with open(g_last_quantile_file, 'rb') as infile:
    g_last = pickle.load(infile)

with open(s_ave_performance_file, 'rb') as infile:
    s_ave = pickle.load(infile)
with open(s_max_performance_file, 'rb') as infile:
    s_max = pickle.load(infile)
with open(s_min_performance_file, 'rb') as infile:
    s_min = pickle.load(infile)
with open(s_cog_performance_file, 'rb') as infile:
    s_cog = pickle.load(infile)
with open(s_variance_file, 'rb') as infile:
    s_var = pickle.load(infile)
with open(s_cog_variance_file, 'rb') as infile:
    s_cog_var = pickle.load(infile)
with open(s_first_quantile_file, 'rb') as infile:
    s_first = pickle.load(infile)
with open(s_last_quantile_file, 'rb') as infile:
    s_last = pickle.load(infile)

# %%
# G
x = range(len(g_ave))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, g_ave, "k-", label="Ave", color=nature_blue)
plt.plot(x, g_max, "k-", label="Max", color=nature_green)
plt.plot(x, g_min, "k-", label="Min", color=nature_orange)
plt.plot(x, g_cog, "k-", label="Cog", color="black")

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\G_performance.png", transparent=True, dpi=300)
plt.show()
# plt.clf()

# %%
# S
x = range(len(s_ave))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, s_ave, "k-", label="Ave", color=nature_blue)
# plt.plot(x, s_max, "k-", label="Max", color=nature_green)
# plt.plot(x, s_min, "k-", label="Min", color=nature_orange)
plt.plot(x, s_cog, "k-", label="Cog", color="black")
plt.plot(x, s_first, "k--", label="First", color="black")
plt.plot(x, s_last, "k:", label="Last", color="black")
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\S_performance.png", transparent=True, dpi=300)
plt.show()
# plt.clf()

# %%
# G & S
x = range(len(s_ave))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, s_ave, "k-", label="S")
plt.plot(x, g_ave, "k--", label="G")
plt.plot(x, s_cog, "k-", label="S", color=nature_blue)
plt.plot(x, g_cog, "k--", label="G", color=nature_blue)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\GS_performance.png", transparent=False, dpi=300)
plt.show()
# plt.clf()

# %%
# Partial and Full
full_data_folder= r"E:\data\gst-0512\Independent_full"
full_g_cog_performance_file = full_data_folder + r"\g_cog_performance_across_K"
full_s_cog_performance_file = full_data_folder + r"\s_cog_performance_across_K"
with open(full_g_cog_performance_file, 'rb') as infile:
    full_g_cog = pickle.load(infile)
with open(full_s_cog_performance_file, 'rb') as infile:
    full_s_cog = pickle.load(infile)
# G & S
x = range(len(s_ave))
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, full_s_cog, "k-", label="Full S", color=nature_orange)
plt.plot(x, s_cog, "k--", label="Partial S", color=nature_orange)
plt.plot(x, full_g_cog, "k-", label="Full G", color=nature_blue)
plt.plot(x, g_cog, "k--", label="Partial G", color=nature_blue)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Performance', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\GS_performance.png", transparent=False, dpi=300)
plt.show()
# plt.clf()
