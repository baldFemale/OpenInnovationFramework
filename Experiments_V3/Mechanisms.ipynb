# %%
from Evaluator import Evaluator
import matplotlib.pyplot as plt
import pickle
import numpy as np
import os
import re
import scipy

# %% [markdown]
# # Composition and its surface mechanism
# ## G/S pool measured separately

# %%
data_folder = r'C:\Python_Workplace\hpc-0422\Experiments_V3\Composition'
output_folder = r'C:\Python_Workplace\hpc-0422\Experiments_V3'
###############################################################
landscape_iteration = 1000
agent_num = 200
search_iteration = 100
# Parameter
N = 9
state_num = 4
knowledge_num = 16
K_list = [2, 4, 6, 8]
frequency_list = [1]
openness_list = [1.0]
quality_list = [1.0]
G_exposed_to_G_list = [0.5]
S_exposed_to_S_list = [0.5]
gs_proportion_list = [0.25, 0.5, 0.75, 1.0]
###############################################################
exposure_type = "Self-interested"

fore_title = "N" + str(N) + "-" + exposure_type
evaluator = Evaluator(data_path=data_folder, output_path=output_folder, )
evaluator.load_iv_configuration(exposure_type=exposure_type, N=N, state_num=state_num, K_list=K_list, frequency_list=frequency_list,
                                openness_list=openness_list, quality_list=quality_list, G_exposed_to_G_list=G_exposed_to_G_list,
                                S_exposed_to_S_list=S_exposed_to_S_list, gs_proportion_list=gs_proportion_list, knowledge_num=knowledge_num)
evaluator.load_simulation_configuration(landscape_iteration=landscape_iteration, agent_num=agent_num, search_iteration=search_iteration)

# Main effect for one dimension except for Direction
# evaluator.generate_one_dimension_figure(title=fore_title, dimension="Openness", y_label="Average", show_variance=False, percentage=0.1, top_coverage=None)

# Surface evolution with search iterations
evaluator.generate_surface_evolution(title=fore_title, dimension="Proportion", GS_flag="G", y_label="Quality")
# Out:
# file_name_reference:  [0.25, 0.5, 0.75, 1.0]
# selected_files_list:  170
# Quality Shape (before):  (4, 4, 1, 1000, 100)
# Quality Shape (after):  (4, 4, 100000)
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists

# %%
evaluator.gs_proportion_list = [0, 0.25, 0.5, 0.75]
evaluator.generate_surface_evolution(title=fore_title, dimension="Proportion", GS_flag="S", y_label="Quality")
# Out:
# file_name_reference:  [0, 0.25, 0.5, 0.75]
# selected_files_list:  170
# Quality Shape (before):  (4, 4, 1, 1000, 100)
# Quality Shape (after):  (4, 4, 100000)
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()

# %%
evaluator.gs_proportion_list = [0.25, 0.5, 0.75, 1.0]
evaluator.generate_surface_evolution(title=fore_title, dimension="Proportion", GS_flag="G", y_label="Utilization")
# Out:
# file_name_reference:  [0.25, 0.5, 0.75, 1.0]
# selected_files_list:  170
# Utilization Shape (before):  (4, 4, 1, 1000, 100)
# Utilization Shape (after):  (4, 4, 100000)
# File Exists
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists

# %%
evaluator.gs_proportion_list = [0, 0.25, 0.5, 0.75]
evaluator.generate_surface_evolution(title=fore_title, dimension="Proportion", GS_flag="S", y_label="Utilization")
# Out:
# file_name_reference:  [0, 0.25, 0.5, 0.75]
# selected_files_list:  170
# Utilization Shape (before):  (4, 4, 1, 1000, 100)
# Utilization Shape (after):  (4, 4, 100000)
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()
# C:\Python_Workplace\OpenInnovationFramework\Experiments_V3\Evaluator.py:775: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = f.add_subplot()

# %%
evaluator.gs_proportion_list = [0.25, 0.5, 0.75, 1.0]
evaluator.generate_surface_evolution(title=fore_title, dimension="Proportion", GS_flag="G", y_label="Divergence")
# Out:
# file_name_reference:  [0.25, 0.5, 0.75, 1.0]
# selected_files_list:  170
# Divergence Shape (before):  (4, 4, 1, 1000, 100)
# Divergence Shape (after):  (4, 4, 100000)
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists

# %%
evaluator.gs_proportion_list = [0, 0.25, 0.5, 0.75]
evaluator.generate_surface_evolution(title=fore_title, dimension="Proportion", GS_flag="S", y_label="Divergence")
# Out:
# file_name_reference:  [0, 0.25, 0.5, 0.75]
# selected_files_list:  170
# Divergence Shape (before):  (4, 4, 1, 1000, 100)
# Divergence Shape (after):  (4, 4, 100000)
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists

# %% [markdown]
# ## Composition and overall pool

# %%
evaluator.gs_proportion_list = [0.25, 0.5, 0.75]
evaluator.generate_surface_evolution(title=fore_title, dimension="Proportion", GS_flag="", y_label="Quality")
# Out:
# file_name_reference:  [0.25, 0.5, 0.75]
# selected_files_list:  170
# Quality Shape (before):  (3, 4, 2, 1000, 100)
# Quality Shape (after):  (3, 4, 200000)
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists

# %%
evaluator.gs_proportion_list = [0.25, 0.5, 0.75]
evaluator.generate_surface_evolution(title=fore_title, dimension="Proportion", GS_flag="", y_label="Utilization")
# Out:
# file_name_reference:  [0.25, 0.5, 0.75]
# selected_files_list:  170
# Utilization Shape (before):  (3, 4, 2, 1000, 100)
# Utilization Shape (after):  (3, 4, 200000)
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists

# %% [markdown]
# # Direction and the counterfactual analysis for surface reinforcement

# %%
data_folder = r'C:\Python_Workplace\hpc-0422\Experiments_V3\Direction'
output_folder = r'C:\Python_Workplace\hpc-0422\Experiments_V3'
###############################################################
landscape_iteration = 1000
agent_num = 200
search_iteration = 100
# Parameter
N = 9
state_num = 4
knowledge_num = 16
K_list = [2, 4, 6, 8]
frequency_list = [1]
openness_list = [1.0]
quality_list = [1.0]
G_exposed_to_G_list = [0, 0.25, 0.5, 0.75, 1.0]
S_exposed_to_S_list = [0, 0.25, 0.5, 0.75, 1.0]
gs_proportion_list = [0.5]
###############################################################
exposure_type = "Self-interested"

fore_title = "N" + str(N) + "-" + exposure_type
evaluator = Evaluator(data_path=data_folder, output_path=output_folder, )
evaluator.load_iv_configuration(exposure_type=exposure_type, N=N, state_num=state_num, K_list=K_list, frequency_list=frequency_list,
                                openness_list=openness_list, quality_list=quality_list, G_exposed_to_G_list=G_exposed_to_G_list,
                                S_exposed_to_S_list=S_exposed_to_S_list, gs_proportion_list=gs_proportion_list, knowledge_num=knowledge_num)
evaluator.load_simulation_configuration(landscape_iteration=landscape_iteration, agent_num=agent_num, search_iteration=search_iteration)

# Surface evolution with search iterations
evaluator.generate_surface_direction(title=fore_title, y_label="Quality", GS_flag="G")
# Out:
# Quality Shape (after):  (3, 4)
# File Exists
# File Exists
# File Exists

# %%
evaluator.generate_surface_direction(title=fore_title, y_label="Quality", GS_flag="S")
# Out:
# Quality Shape (after):  (3, 4)
# File Exists
# File Exists
# File Exists
# File Exists

# %%
evaluator.generate_surface_direction(title=fore_title, y_label="Utilization", GS_flag="G")
# Out:
# Utilization Shape (after):  (3, 4)

# %%
evaluator.generate_surface_direction(title=fore_title, y_label="Utilization", GS_flag="S")
# Out:
# Utilization Shape (after):  (3, 4)
# File Exists
# File Exists
# File Exists
# File Exists
# File Exists

# %%
evaluator.generate_surface_direction(title=fore_title, y_label="Divergence", GS_flag="G")

# %%
evaluator.generate_surface_direction(title=fore_title, y_label="Divergence", GS_flag="S")
