# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
data_folder = r"E:\data\gst-0815-23\Mechanism_7_use_satisfying\JointSatisfaction_across_Overlap"
overlap_list = [0, 1, 2, 3]
gg_overlap_list = [3, 4, 5]
gg_satisfaction_across_K_overlap, gs_satisfaction_across_K_overlap, ss_satisfaction_across_K_overlap, sg_satisfaction_across_K_overlap = [], [], [], []
for overlap in overlap_list:
    gs_satisfaction_file = data_folder + r"\gs_joint_satisfaction_across_K_overlap_{0}".format(overlap)
    ss_satisfaction_file = data_folder + r"\ss_joint_satisfaction_across_K_overlap_{0}".format(overlap)
    sg_satisfaction_file = data_folder + r"\sg_joint_satisfaction_across_K_overlap_{0}".format(overlap)
    
    with open(gs_satisfaction_file, 'rb') as infile:
        gs_satisfaction = pickle.load(infile)
    with open(ss_satisfaction_file, 'rb') as infile:
        ss_satisfaction = pickle.load(infile)
    with open(sg_satisfaction_file, 'rb') as infile:
        sg_satisfaction = pickle.load(infile)
    
    gs_satisfaction_across_K_overlap.append(gs_satisfaction)
    ss_satisfaction_across_K_overlap.append(ss_satisfaction)
    sg_satisfaction_across_K_overlap.append(sg_satisfaction)

for gg_overlap in gg_overlap_list:
    
    gg_satisfaction_file = data_folder + r"\gg_joint_satisfaction_across_K_overlap_{0}".format(gg_overlap)
    with open(gg_satisfaction_file, 'rb') as infile:
        gg_satisfaction = pickle.load(infile)
    gg_satisfaction_across_K_overlap.append(gg_satisfaction)

    print(gg_satisfaction)
# print(np.array(ss_satisfaction_across_K_alpha).shape)
# print(gs_satisfaction_across_K_alpha)
# print(sg_satisfaction_across_K_alpha)
# Out:
# [0.7689488125000001, 0.7203265625000003, 0.6729943749999999, 0.6335706875000001, 0.6045104999999998, 0.5764204374999998, 0.5561428750000001, 0.5375515000000002, 0.5287691250000001]
# [0.8169209374999999, 0.7703001874999998, 0.7065770624999997, 0.6622431249999998, 0.6255638750000002, 0.5919154375000002, 0.5645315000000004, 0.5468300625000002, 0.5333461249999999]
# [0.8455798749999999, 0.8003170625000001, 0.7493063750000002, 0.6905998749999999, 0.6452327500000001, 0.6014730000000003, 0.577104375, 0.5543976250000001, 0.5374194999999999]

# %%
# GG Overlap
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gg_satisfaction_across_K_overlap[0], "-", label="GG Overlap=3", color=nature_blue)
plt.plot(x, gg_satisfaction_across_K_overlap[1], "-", label="GG Overlap=4", color=nature_green)
plt.plot(x, gg_satisfaction_across_K_overlap[2], "-", label="GG Overlap=5", color=nature_orange)
# plt.plot(x, gg_satisfaction_across_K_overlap[3], "-", label="GG Overlap=3", color=morandi_red)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.title("GG")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_SS.png", transparent=True, dpi=300)
plt.show()

# %%
# SG Overlap
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, sg_satisfaction_across_K_overlap[0], "-", label="SG Overlap=0", color=nature_blue)
plt.plot(x, sg_satisfaction_across_K_overlap[1], "-", label="SG Overlap=1", color=nature_green)
plt.plot(x, sg_satisfaction_across_K_overlap[2], "-", label="SG Overlap=2", color=nature_orange)
plt.plot(x, sg_satisfaction_across_K_overlap[3], "-", label="SG Overlap=3", color=morandi_red)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.title("SG")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_SG.png", transparent=True, dpi=300)
plt.show()

# %%
# SS Overlap
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, ss_satisfaction_across_K_overlap[0], "-", label="SS Overlap=0", color=nature_blue)
plt.plot(x, ss_satisfaction_across_K_overlap[1], "-", label="SS Overlap=1", color=nature_green)
plt.plot(x, ss_satisfaction_across_K_overlap[2], "-", label="SS Overlap=2", color=nature_orange)
plt.plot(x, ss_satisfaction_across_K_overlap[3], "-", label="SS Overlap=3", color=morandi_red)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.title("SS")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_SS.png", transparent=True, dpi=300)
plt.show()

# %%
# GS Overlap
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gs_satisfaction_across_K_overlap[0], "-", label="GS Overlap=0", color=nature_blue)
plt.plot(x, gs_satisfaction_across_K_overlap[1], "-", label="GS Overlap=1", color=nature_green)
plt.plot(x, gs_satisfaction_across_K_overlap[2], "-", label="GS Overlap=2", color=nature_orange)
plt.plot(x, gs_satisfaction_across_K_overlap[3], "-", label="GS Overlap=3", color=morandi_red)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.title("GS")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_GS.png", transparent=True, dpi=300)
plt.show()

# %%
# Integrate S
S_satisfaction_across_K_overlap = []
for ss_across_K, gs_across_K in zip(ss_satisfaction_across_K_overlap, gs_satisfaction_across_K_overlap):
    new_s_list = []
    for ss, gs in zip(ss_across_K, gs_across_K):
        new_s = 0.5 * (ss + gs)
        new_s_list.append(new_s)
    S_satisfaction_across_K_overlap.append(new_s_list)
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, S_satisfaction_across_K_overlap[0], "-", label="S Overlap=1", color=nature_blue)
plt.plot(x, S_satisfaction_across_K_overlap[1], "-", label="S Overlap=2", color=nature_green)
plt.plot(x, S_satisfaction_across_K_overlap[2], "-", label="S Overlap=3", color=nature_orange)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
# plt.title("SS")
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_S.png", transparent=True, dpi=300)
plt.show()

# %%
# Integrate G
G_satisfaction_across_K_overlap = []
for gg_across_K, sg_across_K in zip(gg_satisfaction_across_K_overlap, sg_satisfaction_across_K_overlap):
    new_g_list = []
    for gg, sg in zip(gg_across_K, sg_across_K):
        new_g = 0.5 * (gg + sg)
        new_g_list.append(new_g)
    G_satisfaction_across_K_overlap.append(new_g_list)
x = range(9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, G_satisfaction_across_K_overlap[0], "-", label="G Overlap=3", color=nature_blue)
plt.plot(x, G_satisfaction_across_K_overlap[1], "-", label="G Overlap=4", color=nature_green)
plt.plot(x, G_satisfaction_across_K_overlap[2], "-", label="G Overlap=5", color=nature_orange)
plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Satisfaction', fontweight='bold', fontsize=12)
plt.xticks(x)
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap_G.png", transparent=True, dpi=300)
plt.show()

# %%
# Integrate G and S
G_satisfaction_across_K_overlap = []
for gg_across_K, sg_across_K in zip(gg_satisfaction_across_K_overlap, sg_satisfaction_across_K_overlap):
    new_g_list = []
    for gg, sg in zip(gg_across_K, sg_across_K):
        new_g = 0.5 * (gg + sg)
        new_g_list.append(new_g)
    G_satisfaction_across_K_overlap.append(new_g_list)

S_satisfaction_across_K_overlap = []
for ss_across_K, gs_across_K in zip(ss_satisfaction_across_K_overlap, gs_satisfaction_across_K_overlap):
    new_s_list = []
    for ss, gs in zip(ss_across_K, gs_across_K):
        new_s = 0.5 * (ss + gs)
        new_s_list.append(new_s)
    S_satisfaction_across_K_overlap.append(new_s_list)
x = range(1, 9)
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, G_satisfaction_across_K_overlap[0][1:], marker='o', linestyle='-', label="G Low Overlap", color=nature_blue)
plt.plot(x, G_satisfaction_across_K_overlap[1][1:], marker='s', linestyle='-', label="G Medium Overlap", color=nature_blue)
plt.plot(x, G_satisfaction_across_K_overlap[2][1:], marker='v', linestyle='-', label="G High Overlap", color=nature_blue)

plt.plot(x, S_satisfaction_across_K_overlap[0][1:], marker='o', linestyle='-', label="S Low Overlap", color=nature_orange)
plt.plot(x, S_satisfaction_across_K_overlap[1][1:], marker='s', linestyle='-', label="S Medium Overlap", color=nature_orange)
plt.plot(x, S_satisfaction_across_K_overlap[2][1:], marker='v', linestyle='-', label="S High Overlap", color=nature_orange)

plt.xlabel('K', fontweight='bold', fontsize=12)
plt.ylabel('Joint Confirmation', fontweight='bold', fontsize=12)
plt.title("(g) Knowledge Overlap")
plt.xticks(x)
plt.legend(frameon=False, fontsize=12)
plt.savefig(data_folder + r"\Joint_Satisfaction_across_Overlap.png", transparent=True, dpi=300)
plt.show()
