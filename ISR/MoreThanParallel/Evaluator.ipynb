# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]

# %%
GG_data_folder = r"/Volumes/T7/data/gst-0112-26/MoreThanParallel"
result_folder = GG_data_folder
GS_data_folder = GG_data_folder
SS_data_folder = GG_data_folder
SG_data_folder = GG_data_folder
# GS_data_folder = r"E:\data\gst-0815-23\Socialization_partial_solution\MoreThanParallel\MoreThanParallel_GS"
# SS_data_folder = r"E:\data\gst-0815-23\Socialization_partial_solution\MoreThanParallel\MoreThanParallel_SS"
# SG_data_folder = r"E:\data\gst-0815-23\Socialization_partial_solution\MoreThanParallel\MoreThanParallel_SG"
agent_num_list = np.arange(50, 850, step=50, dtype=int).tolist()
gg_performance_across_K_size, gg_best_performance_across_K_size, gg_variance_across_K_size, gg_diversity_across_K_size = [], [], [], []
gs_performance_across_K_size, gs_best_performance_across_K_size, gs_variance_across_K_size, gs_diversity_across_K_size = [], [], [], []
ss_performance_across_K_size, ss_best_performance_across_K_size, ss_variance_across_K_size, ss_diversity_across_K_size = [], [], [], []
sg_performance_across_K_size, sg_best_performance_across_K_size, sg_variance_across_K_size, sg_diversity_across_K_size = [], [], [], []
for agent_num in agent_num_list:
    gg_performance_file = GG_data_folder + r"/gg_performance_across_K_size_{0}".format(agent_num)
    gg_best_performance_file = GG_data_folder + r"/gg_best_performance_across_K_size_{0}".format(agent_num)
    gg_diversity_file = GG_data_folder + r"/gg_diversity_across_K_size_{0}".format(agent_num)
    gg_variance_file = GG_data_folder + r"/gg_variance_across_K_size_{0}".format(agent_num)

    gs_performance_file = GS_data_folder + r"/gs_performance_across_K_size_{0}".format(agent_num)
    gs_best_performance_file = GS_data_folder + r"/gs_best_performance_across_K_size_{0}".format(agent_num)
    gs_diversity_file = GS_data_folder + r"/gs_diversity_across_K_size_{0}".format(agent_num)
    gs_variance_file = GS_data_folder + r"/gs_variance_across_K_size_{0}".format(agent_num)
    
    ss_performance_file = SS_data_folder + r"/ss_performance_across_K_size_{0}".format(agent_num)
    ss_best_performance_file = SS_data_folder + r"/ss_best_performance_across_K_size_{0}".format(agent_num)
    ss_diversity_file = SS_data_folder + r"/ss_diversity_across_K_size_{0}".format(agent_num)
    ss_variance_file = SS_data_folder + r"/ss_variance_across_K_size_{0}".format(agent_num)
    
    sg_performance_file = SG_data_folder + r"/sg_performance_across_K_size_{0}".format(agent_num)
    sg_best_performance_file = SG_data_folder + r"/sg_best_performance_across_K_size_{0}".format(agent_num)
    sg_diversity_file = SG_data_folder + r"/sg_diversity_across_K_size_{0}".format(agent_num)
    sg_variance_file = SG_data_folder + r"/sg_variance_across_K_size_{0}".format(agent_num)
    
    with open(gg_performance_file, 'rb') as infile:
        gg_fitness = pickle.load(infile)
    with open(gg_best_performance_file, 'rb') as infile:
        gg_best_performance = pickle.load(infile)
    with open(gg_variance_file, 'rb') as infile:
        gg_variance = pickle.load(infile)
    with open(gg_diversity_file, 'rb') as infile:
        gg_diversity = pickle.load(infile)

    with open(gs_performance_file, 'rb') as infile:
        gs_fitness = pickle.load(infile)
    with open(gs_best_performance_file, 'rb') as infile:
        gs_best_performance = pickle.load(infile)
    with open(gs_variance_file, 'rb') as infile:
        gs_variance = pickle.load(infile)
    with open(gs_diversity_file, 'rb') as infile:
        gs_diversity = pickle.load(infile)

    with open(ss_performance_file, 'rb') as infile:
        ss_fitness = pickle.load(infile)
    with open(ss_best_performance_file, 'rb') as infile:
        ss_best_performance = pickle.load(infile)
    with open(ss_variance_file, 'rb') as infile:
        ss_variance = pickle.load(infile)
    with open(ss_diversity_file, 'rb') as infile:
        ss_diversity = pickle.load(infile)

    with open(sg_performance_file, 'rb') as infile:
        sg_fitness = pickle.load(infile)
    with open(sg_best_performance_file, 'rb') as infile:
        sg_best_performance = pickle.load(infile)
    with open(sg_variance_file, 'rb') as infile:
        sg_variance = pickle.load(infile)
    with open(sg_diversity_file, 'rb') as infile:
        sg_diversity = pickle.load(infile)
    
    gg_performance_across_K_size.append(gg_fitness)
    gg_best_performance_across_K_size.append(gg_best_performance)
    gg_variance_across_K_size.append(gg_variance)
    gg_diversity_across_K_size.append(gg_diversity)
    
    gs_performance_across_K_size.append(gs_fitness)
    gs_best_performance_across_K_size.append(gs_best_performance)
    gs_variance_across_K_size.append(gs_variance)
    gs_diversity_across_K_size.append(gs_diversity)
    
    ss_performance_across_K_size.append(ss_fitness)
    ss_best_performance_across_K_size.append(ss_best_performance)
    ss_variance_across_K_size.append(ss_variance)
    ss_diversity_across_K_size.append(ss_diversity)
    
    sg_performance_across_K_size.append(sg_fitness)
    sg_best_performance_across_K_size.append(sg_best_performance)
    sg_variance_across_K_size.append(sg_variance)
    sg_diversity_across_K_size.append(sg_diversity)
    
print([each / 18 for each in gg_diversity_across_K_size[0]])
print(gg_diversity_across_K_size[1])
print(gg_diversity_across_K_size[2])
print(gg_diversity_across_K_size[3])
print(gg_diversity_across_K_size[4])
# Out:
# [2.53125, 2.460694444444444, 2.4469444444444446, 2.4475, 2.4604166666666667, 2.470972222222222, 2.488611111111111, 2.512916666666667, 2.5091666666666668]
# [84.8425, 81.6, 80.78, 80.6475, 81.205, 81.67, 82.5525, 83.1225, 83.3675]
# [119.2325, 114.1575, 111.915, 112.105, 113.1575, 114.375, 115.77, 116.335, 116.3625]
# [148.1475, 141.6775, 138.1375, 139.9, 142.04, 142.71, 144.6975, 145.92, 146.26]
# [176.085, 165.7775, 163.4525, 163.3675, 166.585, 168.77, 170.445, 172.6325, 172.4625]

# %%
# Baseline: independent search in reproducing parallel search
baseline_folder =r"/Volumes/T7/data/gst-0815-23/Pre-Test/Parallel_Search_9"
agent_num_list = np.arange(50, 850, step=50, dtype=int).tolist()  # for diversity
g_best_performance_across_K_size, s_best_performance_across_K_size = [], []
g_diversity_across_K_size, s_diversity_across_K_size = [], []
for agent_num in agent_num_list:
    g_best_performance_file = baseline_folder + r"/g_best_performance_across_K_size_{0}".format(agent_num)
    s_best_performance_file = baseline_folder + r"/s_best_performance_across_K_size_{0}".format(agent_num)

    g_diversity_file = baseline_folder + r"/g_partial_unique_diversity_across_K_size_{0}".format(agent_num)
    s_diversity_file = baseline_folder + r"/s_partial_unique_diversity_across_K_size_{0}".format(agent_num)

    with open(g_best_performance_file, 'rb') as infile:
        g_best_fitness = pickle.load(infile)
    with open(s_best_performance_file, 'rb') as infile:
        s_best_fitness = pickle.load(infile)

    with open(g_diversity_file, 'rb') as infile:
        g_diversity = pickle.load(infile)
    with open(s_diversity_file, 'rb') as infile:
        s_diversity = pickle.load(infile)

    g_best_performance_across_K_size.append(g_best_fitness)
    s_best_performance_across_K_size.append(s_best_fitness)
    g_diversity_across_K_size.append(g_diversity)
    s_diversity_across_K_size.append(s_diversity)
print(s_diversity_across_K_size[0])
print(s_diversity_across_K_size[1])
# Out:
# [37.88, 47.09, 48.925, 49.4625, 49.63, 49.73, 49.68, 49.75, 49.7725]
# [58.7525, 88.8375, 95.605, 97.8875, 98.575, 98.92, 98.9275, 98.9975, 99.005]

# %%
# # GS Average Fitness Given the Same K and Varying Agent Numbers
# result_folder = r"E:\data\gst-0815-23\Socialization_partial_solution\MoreThanParallel"
# for index in range(9):
#     g1_fitness_across_size, g2_fitness_across_size = [], []
#     for g1_fitness, g2_fitness in zip(gg_fitness_across_K_size, sg_fitness_across_K_size):
#         g1_fitness_across_size.append(g1_fitness[index])
#         g2_fitness_across_size.append(g2_fitness[index])
#     
#     s1_fitness_across_size, s2_fitness_across_size = [], []
#     for s1_fitness, s2_fitness in zip(ss_fitness_across_K_size, gs_fitness_across_K_size):
#         s1_fitness_across_size.append(s1_fitness[index])
#         s2_fitness_across_size.append(s2_fitness[index])
#         
#     
#     x = agent_num_list
#     fig, ax = plt.subplots()
#     ax.spines["left"].set_linewidth(1.5)
#     ax.spines["right"].set_linewidth(1.5)
#     ax.spines["top"].set_linewidth(1.5)
#     ax.spines["bottom"].set_linewidth(1.5)
#     plt.plot(x, g1_fitness_across_size, "v-", label="G1", color=nature_blue)
#     plt.plot(x, g2_fitness_across_size, "v--", label="G2", color=nature_blue)
#     
#     plt.plot(x, s1_fitness_across_size, "s-", label="S1", color=nature_orange)
#     plt.plot(x, s2_fitness_across_size, "s--", label="S2", color=nature_orange)
#     
#     plt.xlabel('Size', fontweight='bold', fontsize=12)
#     plt.ylabel('Performance', fontweight='bold', fontsize=12)
#     # plt.xticks(x)
#     plt.title("$K={0}$".format(index))
#     plt.legend(frameon=False, ncol=1, fontsize=12)
#     plt.savefig(result_folder + r"\GS_average_performance_K_{0}.png".format(index), transparent=True, dpi=300)
#     plt.show()

# %%
# Generalist Best Performance
gg_fitness_across_size_K, sg_fitness_across_size_K = [], []
g_baseline_across_size_K, s_baseline_across_size_K = [], []
for index in range(9):
    gg_fitness_across_size, sg_fitness_across_size = [], []
    for gg_fitness, sg_fitness in zip(gg_best_performance_across_K_size, sg_best_performance_across_K_size):
        gg_fitness_across_size.append(gg_fitness[index])
        sg_fitness_across_size.append(sg_fitness[index])
    gg_fitness_across_size_K.append(gg_fitness_across_size)
    sg_fitness_across_size_K.append(sg_fitness_across_size)
        
    g_baseline_across_size, s_baseline_across_size = [], []
    for g_fitness, s_fitness in zip(g_best_performance_across_K_size, s_best_performance_across_K_size):
        g_baseline_across_size.append(g_fitness[index])
        s_baseline_across_size.append(s_fitness[index])
    g_baseline_across_size_K.append(g_baseline_across_size)
    s_baseline_across_size_K.append(s_baseline_across_size)
    
x = agent_num_list
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gg_fitness_across_size_K[2], "-", marker='v', label=r"G$\rightarrow$G", color="k")
plt.plot(x, sg_fitness_across_size_K[2], "-", marker='s', label=r"S$\rightarrow$G", color="k")
plt.plot(x, g_baseline_across_size_K[2], "--", marker='', label="G", color="k")

plt.xlabel('Crowd Size', fontweight='bold', fontsize=12)
plt.ylabel('Maximum Fitness', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.ylim(0.85, 1.00)
plt.title(r"(a) Low Complexity \n $K=2, N=9, \alpha=0.25, |\mathbb{D}|=12$")
plt.legend(frameon=False, ncol=1, fontsize=12, loc='lower right')
plt.savefig(result_folder + r"/Results/G_best_performance_K_2.png", transparent=True, dpi=300)
plt.show()

x = agent_num_list
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gg_fitness_across_size_K[8], "-", marker='v', label=r"G$\rightarrow$G", color="k")
plt.plot(x, sg_fitness_across_size_K[8], "-", marker='s', label=r"S$\rightarrow$G", color="k")
plt.plot(x, g_baseline_across_size_K[8], "--", marker='', label="G", color="k")

plt.xlabel('Crowd Size', fontweight='bold', fontsize=12)
plt.ylabel('Breakthrough Likelihood', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.ylim(0.85, 1.00)
plt.title(r"(b) High Complexity \n $K=8, N=9, \alpha=0.25, |\mathbb{D}|=12$")
plt.legend(frameon=False, ncol=1, fontsize=12, loc='lower right')
plt.savefig(result_folder + r"/Results/G_best_performance_K_8.png", transparent=True, dpi=300)
plt.show()

# %%
# Specialists Best Performance
ss_performance_across_size_K, gs_performance_across_size_K = [], []
g_baseline_across_size_K, s_baseline_across_size_K = [], []
for index in range(9):
    ss_performance_across_size, gs_performance_across_size = [], []
    for ss_fitness, gs_fitness in zip(ss_best_performance_across_K_size, gs_best_performance_across_K_size):
        ss_performance_across_size.append(ss_fitness[index])
        gs_performance_across_size.append(gs_fitness[index])
    ss_performance_across_size_K.append(ss_performance_across_size)
    gs_performance_across_size_K.append(gs_performance_across_size)
    
    g_baseline_across_size, s_baseline_across_size = [], []
    for g_fitness, s_fitness in zip(g_best_performance_across_K_size, s_best_performance_across_K_size):
        g_baseline_across_size.append(g_fitness[index])
        s_baseline_across_size.append(s_fitness[index])
    g_baseline_across_size_K.append(g_baseline_across_size)
    s_baseline_across_size_K.append(s_baseline_across_size)

x = agent_num_list
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, ss_performance_across_size_K[2], "-", marker='v', label=r"S$\rightarrow$S", color="k")
plt.plot(x, gs_performance_across_size_K[2], "-", marker='s', label=r"G$\rightarrow$S", color="k")
plt.plot(x, s_baseline_across_size_K[2], "--", marker='', label="S", color="k")

plt.xlabel('Crowd Size', fontweight='bold', fontsize=12)
plt.ylabel('Breakthrough Likelihood', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.ylim(0.85, 1.00)
plt.title(r"(a) Low Complexity \n $K=2, N=9, \alpha=0.25, |\mathbb{D}|=12$")
plt.legend(frameon=False, ncol=1, fontsize=12, loc='lower right')
plt.savefig(result_folder + r"/Results/S_best_performance_K_2.png", transparent=True, dpi=300)
plt.show()

x = agent_num_list
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, ss_performance_across_size_K[8], "-", marker='v', label=r"S$\rightarrow$S", color="k")
plt.plot(x, gs_performance_across_size_K[8], "-", marker='s', label=r"G$\rightarrow$S", color="k")
plt.plot(x, s_baseline_across_size_K[8], "--", marker='', label="S", color="k")

plt.xlabel('Crowd Size', fontweight='bold', fontsize=12)
plt.ylabel('Breakthrough Likelihood', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.ylim(0.85, 1.00)
plt.title(r"(b) High Complexity \n $K=8, N=9, \alpha=0.25, |\mathbb{D}|=12$")
plt.legend(frameon=False, ncol=1, fontsize=12, loc='lower right')
plt.savefig(result_folder + r"/Results/S_best_performance_K_8.png", transparent=True, dpi=300)
plt.show()

# %%
# Generalist Diversity
gg_diversity_across_size_K, sg_diversity_across_size_K = [], []
g_diversity_baseline_across_size_K, s_diversity_baseline_across_size_K = [], []
for index in range(9):
    gg_diversity_across_size, sg_diversity_across_size = [], []
    for gg_diversity, sg_diversity in zip(gg_diversity_across_K_size, sg_diversity_across_K_size):
        gg_diversity_across_size.append(gg_diversity[index])
        sg_diversity_across_size.append(sg_diversity[index])
    gg_diversity_across_size_K.append(gg_diversity_across_size)
    sg_diversity_across_size_K.append(sg_diversity_across_size)

    g_diversity_baseline_across_size, s_diversity_baseline_across_size = [], []
    for g_diversity_baseline, s_diversity_baseline in zip(g_diversity_across_K_size, s_diversity_across_K_size):
        g_diversity_baseline_across_size.append(g_diversity_baseline[index])
        s_diversity_baseline_across_size.append(s_diversity_baseline[index])
    g_diversity_baseline_across_size_K.append(g_diversity_baseline_across_size)
    s_diversity_baseline_across_size_K.append(s_diversity_baseline_across_size)
    # offset = 1.5
    # g1_diversity_across_size = [a * b + offset for a, b in zip(agent_num_list, g1_diversity_across_size)]
    # g2_diversity_across_size = [a * b - offset for a, b in zip(agent_num_list, g2_diversity_across_size)]
    # s1_diversity_across_size = [a * b + offset for a, b in zip(agent_num_list, s1_diversity_across_size)]
    # s2_diversity_across_size = [a * b - offset for a, b in zip(agent_num_list, s2_diversity_across_size)]
    # g_diversity_baseline_across_size = [a * b + offset for a, b in zip(agent_num_list, g_diversity_baseline_across_size)]
    # s_diversity_baseline_across_size = [a * b - offset for a, b in zip(agent_num_list, s_diversity_baseline_across_size)]

x = agent_num_list
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gg_diversity_across_size_K[1], "-", marker='v', label=r"G$\rightarrow$G", color="k")
plt.plot(x, sg_diversity_across_size_K[1], "-", marker='s', label=r"S$\rightarrow$G", color="k")
plt.plot(x, g_diversity_baseline_across_size_K[1], "--", marker='o', label="G", color="k")

plt.xlabel('Crowd Size', fontweight='bold', fontsize=12)
plt.ylabel('Solution Diversity', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.ylim(0, 800)
plt.title(r"(a) Low Complexity \n $K=2, N=9, \alpha=0.25, |\mathbb{D}|=12$")
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(result_folder + r"/Results/G_diversity_K_2.png", transparent=True, dpi=300)
plt.show()

x = agent_num_list
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, gg_diversity_across_size_K[8], "-", marker='v', label=r"G$\rightarrow$G", color="k")
plt.plot(x, sg_diversity_across_size_K[8], "-", marker='s', label=r"S$\rightarrow$G", color="k")
plt.plot(x, g_diversity_baseline_across_size_K[8], "--", marker='o', label="G", color="k")

plt.xlabel('Crowd Size', fontweight='bold', fontsize=12)
plt.ylabel('Solution Diversity', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.ylim(0, 800)
plt.title(r"(b) High Complexity \n $K=8, N=9, \alpha=0.25, |\mathbb{D}|=12$")
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(result_folder + r"/Results/G_diversity_K_8.png", transparent=True, dpi=300)
plt.show()

# %%
# Generalist Diversity
ss_diversity_across_size_K, gs_diversity_across_size_K = [], []
g_diversity_baseline_across_size_K, s_diversity_baseline_across_size_K = [], []
for index in range(9):
    ss_diversity_across_size, gs_diversity_across_size = [], []
    for ss_diversity, gs_diversity in zip(ss_diversity_across_K_size, gs_diversity_across_K_size):
        ss_diversity_across_size.append(ss_diversity[index])
        gs_diversity_across_size.append(gs_diversity[index])
    ss_diversity_across_size_K.append(ss_diversity_across_size)
    gs_diversity_across_size_K.append(gs_diversity_across_size)

    g_diversity_baseline_across_size, s_diversity_baseline_across_size = [], []
    for g_diversity_baseline, s_diversity_baseline in zip(g_diversity_across_K_size, s_diversity_across_K_size):
        g_diversity_baseline_across_size.append(g_diversity_baseline[index])
        s_diversity_baseline_across_size.append(s_diversity_baseline[index])
    g_diversity_baseline_across_size_K.append(g_diversity_baseline_across_size)
    s_diversity_baseline_across_size_K.append(s_diversity_baseline_across_size)
    # offset = 1.5
    # g1_diversity_across_size = [a * b + offset for a, b in zip(agent_num_list, g1_diversity_across_size)]
    # g2_diversity_across_size = [a * b - offset for a, b in zip(agent_num_list, g2_diversity_across_size)]
    # s1_diversity_across_size = [a * b + offset for a, b in zip(agent_num_list, s1_diversity_across_size)]
    # s2_diversity_across_size = [a * b - offset for a, b in zip(agent_num_list, s2_diversity_across_size)]
    # g_diversity_baseline_across_size = [a * b + offset for a, b in zip(agent_num_list, g_diversity_baseline_across_size)]
    # s_diversity_baseline_across_size = [a * b - offset for a, b in zip(agent_num_list, s_diversity_baseline_across_size)]

x = agent_num_list
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, ss_diversity_across_size_K[1], "-", marker='v', label=r"S$\rightarrow$S", color="k")
plt.plot(x, gs_diversity_across_size_K[1], "-", marker='s', label=r"G$\rightarrow$S", color="k")
plt.plot(x, s_diversity_baseline_across_size_K[1], "--", marker='o', label="S", color="k")

plt.xlabel('Crowd Size', fontweight='bold', fontsize=12)
plt.ylabel('Solution Diversity', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.ylim(0, 800)
plt.title(r"(a) Low Complexity \n $K=2, N=9, \alpha=0.25, |\mathbb{D}|=12$")
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(result_folder + r"/Results/S_diversity_K_2.png", transparent=True, dpi=300)
plt.show()

x = agent_num_list
fig, ax = plt.subplots()
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)
plt.plot(x, ss_diversity_across_size_K[8], "-", marker='v', label=r"S$\rightarrow$S", color="k")
plt.plot(x, gs_diversity_across_size_K[8], "-", marker='s', label=r"G$\rightarrow$S", color="k")
plt.plot(x, s_diversity_baseline_across_size_K[8], "--", marker='o', label="S", color="k")

plt.xlabel('Crowd Size', fontweight='bold', fontsize=12)
plt.ylabel('Solution Diversity', fontweight='bold', fontsize=12)
# plt.xticks(x)
plt.ylim(0, 800)
plt.title(r"(b) High Complexity \n $K=8, N=9, \alpha=0.25, |\mathbb{D}|=12$")
plt.legend(frameon=False, ncol=1, fontsize=12)
plt.savefig(result_folder + r"/Results/S_diversity_K_8.png", transparent=True, dpi=300)
plt.show()
