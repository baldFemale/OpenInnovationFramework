# %% [markdown]
# # Visibility Timing Evaluator
#
# This notebook evaluates the new visibility-timing experiments generated by the four running scripts:
#
# - `G_send_to_G_visibility_timing.py` → `gg_*`
# - `G_send_to_S_visibility_timing.py` → `gs_*`
# - `S_send_to_G_visibility_timing.py` → `sg_*`
# - `S_send_to_S_visibility_timing.py` → `ss_*`
#
# The figures below report the same analyses as the original evaluator, but restrict the reported results to the focal complexity range K = 4–8. Smaller rank means a better solution, so rank figures invert the y-axis.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
legend_properties = {'weight':'bold'}
nus_blue = "#003D7C"
nus_orange = "#EF7C00"
# Nature three colors
nature_orange = "#F16C23"
nature_blue = "#2B6A99"
nature_green = "#1B7C3D"
# Morandi six colors
morandi_blue = "#046586"
morandi_green =  "#28A9A1"
morandi_yellow = "#C9A77C"
morandi_orange = "#F4A016"
morandi_pink = "#F6BBC6"
morandi_red = "#E71F19"
morandi_purple = "#B08BEB"
# Others
shallow_grey = "#D3D4D3"
deep_grey = "#A6ABB6"
# Red and Blue
strong_red = "#A61C5D"
strong_blue = "#1B64A4"

# Shallow-deep pair
shallow_purple = "#EAD7EA"
deep_purple = "#BA9DB9"
shallow_cyan = "#A9D5E0"
deep_cyan = "#48C0BF"
shallow_blue = "#B6DAEC"
deep_blue = "#98CFE4"
shallow_pink = "#F5E0E5"
deep_pink = "#E5A7B6"
shallow_green = "#C2DED0"
deep_green = "#A5C6B1"

color_pairs = [[shallow_purple, deep_purple],  [shallow_green, deep_green],
               [shallow_blue, deep_blue], [shallow_pink, deep_pink], [shallow_cyan, deep_cyan],
               [shallow_grey, deep_grey]]
morandi_colors = [morandi_blue, morandi_green, morandi_yellow, morandi_orange, morandi_pink, morandi_red, morandi_purple]
import os
from pathlib import Path

# %%
from pathlib import Path
import pickle
import numpy as np

# =========================
# Configuration
# =========================
result_folder = Path(r"/Volumes/T7/data/gst-0112-26/Timing")

agent_num = 200

# The raw output files store results across the full K range, K = 0,...,8.
# For the focal theoretical analysis, report only K = 4,...,8.
all_K_list = list(range(9))
K_list = list(range(1, 9))
K_indices = [all_K_list.index(K) for K in K_list]

visibility_start_list = [0, 50, 100, 150, 200]

condition_labels = {
    "gg": "G → G",
    "gs": "G → S",
    "sg": "S → G",
    "ss": "S → S",
}

dv_labels = {
    "breakthrough_rank": "Best solution rank",
    "breakthrough_fitness": "Best solution fitness",
    "diversity": "Diversity",
}

def load_pickle(path):
    with open(path, "rb") as infile:
        return pickle.load(infile)

def result_file(prefix, visibility_start, dv):
    return result_folder / f"{prefix}_visibility_start_{visibility_start}_{dv}_across_K_size_{agent_num}"

# =========================
# Diagnose available files
# =========================
print("Result folder:", result_folder)
print("Folder exists:", result_folder.exists())

available_files = sorted([p.name for p in result_folder.iterdir()]) if result_folder.exists() else []
print("Number of files in folder:", len(available_files))
print("First 10 files:")
for name in available_files[:10]:
    print("  ", name)

# =========================
# Load results
# =========================
def load_visibility_timing_results(prefixes=("gg", "gs", "sg", "ss"), strict=True):
    data = {}
    missing_files = []

    for prefix in prefixes:
        data[prefix] = {}

        for dv in dv_labels:
            rows = []

            for visibility_start in visibility_start_list:
                path = result_file(prefix, visibility_start, dv)

                if not path.exists():
                    missing_files.append(path)
                    continue

                values = np.asarray(load_pickle(path), dtype=float)
                rows.append(values)

            if rows:
                data[prefix][dv] = np.vstack(rows)

    if missing_files:
        print("\nMissing files:")
        for path in missing_files[:30]:
            print("  -", path.name)

        if len(missing_files) > 30:
            print(f"  ... and {len(missing_files) - 30} more")

        print("\nPossible causes:")
        print("1. result_folder is not the folder where the scripts saved outputs.")
        print("2. Some scripts have not finished.")
        print("3. agent_num is different from the saved file name.")
        print("4. File prefix is different, e.g., sg/gs/ss/gg.")

        if strict:
            raise FileNotFoundError("Some expected result files are missing.")

    return data

data = load_visibility_timing_results(strict=True)

# Keep only the focal K range.
# Each loaded array is visibility_start × K, so this subsets the K columns.
for prefix in data:
    for dv in data[prefix]:
        data[prefix][dv] = data[prefix][dv][:, K_indices]

print("\nReporting focal K range:", K_list)

# Quick shape check
print("\nLoaded data shapes:")
for prefix in data:
    for dv in data[prefix]:
        print(prefix, dv, data[prefix][dv].shape)
# Out:
# Result folder: /Volumes/T7/data/gst-0112-26/Timing
# Folder exists: True
# Number of files in folder: 192
# First 10 files:
#    ._Crowd.py
#    ._G_send_to_G_visibility_timing.py
#    ._G_send_to_S_visibility_timing.py
#    ._Generalist.py
#    ._Landscape.py
#    ._S_send_to_G_visibility_timing.py
#    ._S_send_to_S_visibility_timing.py
#    ._Specialist.py
#    ._figure_1_best_rank_across_visibility_timing.png
#    ._figure_1_best_rank_across_visibility_timing_K4_K8.png
#
# Reporting focal K range: [1, 2, 3, 4, 5, 6, 7, 8]
#
# Loaded data shapes:
# gg breakthrough_rank (5, 8)
# gg breakthrough_fitness (5, 8)
# gg diversity (5, 8)
# gs breakthrough_rank (5, 8)
# gs breakthrough_fitness (5, 8)
# gs diversity (5, 8)
# sg breakthrough_rank (5, 8)
# sg breakthrough_fitness (5, 8)
# sg diversity (5, 8)
# ss breakthrough_rank (5, 8)
# ss breakthrough_fitness (5, 8)
# ss diversity (5, 8)

# %%
# =========================
# Figure 1: Main figure — best solution rank across visibility timing
# =========================
fig, ax = plt.subplots(figsize=(7.2, 5.0))
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

condition_colors = {
    "gg": morandi_blue,
    "gs": morandi_orange,
    "sg": morandi_green,
    "ss": morandi_purple,
}

x = visibility_start_list
for prefix in ["gg", "gs", "sg", "ss"]:
    # Average across focal K = 4,...,8 to show the main timing pattern.
    y = data[prefix]["breakthrough_rank"].mean(axis=1)
    ax.plot(x, y, marker="o", linewidth=2.5, markersize=7,
            label=condition_labels[prefix], color=condition_colors[prefix])

ax.invert_yaxis()  # smaller rank means better solution; invert so better is visually higher
ax.set_xlabel("Visibility start", fontweight="bold", fontsize=12)
ax.set_ylabel("Best solution rank (lower is better)", fontweight="bold", fontsize=12)
ax.set_title("Best Rank of Solution Across Visibility Timing (K=4–8)", fontweight="bold", fontsize=13)
ax.legend(frameon=False, prop=legend_properties)
ax.grid(alpha=0.25)
plt.tight_layout()

output_path = result_folder / "figure_1_best_rank_across_visibility_timing_K4_K8.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
plt.show()
print("Saved:", output_path)
# Out:
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_1_best_rank_across_visibility_timing_K4_K8.png

# %%
# =========================
# Figure 2: Best solution rank across visibility timing, averaged across G-S conditions
# =========================
fig, ax = plt.subplots(figsize=(7.2, 5.0))
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

x = visibility_start_list

# Average across focal K = 4,...,8 and the four G-S visibility conditions.
y = np.mean([data[prefix]["breakthrough_rank"].mean(axis=1) for prefix in ["gg", "gs", "sg", "ss"]], axis=0)

ax.plot(x, y, marker="o", linewidth=2.5, markersize=7, color=morandi_blue)

ax.invert_yaxis()
ax.set_xlabel("Visibility start", fontweight="bold", fontsize=12)
ax.set_ylabel("Best solution rank (lower is better)", fontweight="bold", fontsize=12)
ax.set_title("Best Rank of Solution Across Visibility Timing (K=4–8)", fontweight="bold", fontsize=13)
ax.grid(alpha=0.25)
plt.tight_layout()

output_path = result_folder / "figure_2_best_rank_timing_average_K4_K8.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
plt.show()
print("Saved:", output_path)
# Out:
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_2_best_rank_timing_average_K4_K8.png

# %%
# =========================
# Figure 2: Best solution fitness across visibility timing
# =========================
fig, ax = plt.subplots(figsize=(7.2, 5.0))
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

x = visibility_start_list
for prefix in ["gg", "gs", "sg", "ss"]:
    y = data[prefix]["breakthrough_fitness"].mean(axis=1)
    ax.plot(x, y, marker="o", linewidth=2.5, markersize=7,
            label=condition_labels[prefix], color=condition_colors[prefix])

ax.set_xlabel("Visibility start", fontweight="bold", fontsize=12)
ax.set_ylabel("Best solution fitness", fontweight="bold", fontsize=12)
ax.set_title("Best Fitness Across Visibility Timing (K=4–8)", fontweight="bold", fontsize=13)
ax.legend(frameon=False, prop=legend_properties)
ax.grid(alpha=0.25)
plt.tight_layout()

output_path = result_folder / "figure_2_best_fitness_across_visibility_timing_K4_K8.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
plt.show()
print("Saved:", output_path)
# Out:
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_2_best_fitness_across_visibility_timing_K4_K8.png

# %%
# =========================
# Figure 3: Diversity across visibility timing
# =========================
fig, ax = plt.subplots(figsize=(7.2, 5.0))
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

x = visibility_start_list
for prefix in ["gg", "gs", "sg", "ss"]:
    y = data[prefix]["diversity"].mean(axis=1)
    ax.plot(x, y, marker="o", linewidth=2.5, markersize=7,
            label=condition_labels[prefix], color=condition_colors[prefix])

ax.set_xlabel("Visibility start", fontweight="bold", fontsize=12)
ax.set_ylabel("Diversity", fontweight="bold", fontsize=12)
ax.set_title("Diversity Across Visibility Timing (K=4–8)", fontweight="bold", fontsize=13)
ax.legend(frameon=False, prop=legend_properties)
ax.grid(alpha=0.25)
plt.tight_layout()

output_path = result_folder / "figure_3_diversity_across_visibility_timing_K4_K8.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
plt.show()
print("Saved:", output_path)
# Out:
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_3_diversity_across_visibility_timing_K4_K8.png

# %%
# =========================
# Figure 4: Detailed rank patterns by K
# =========================
# This figure reports the detailed rank patterns within the focal K = 4,...,8 range.
for prefix in ["gg", "gs", "sg", "ss"]:
    fig, ax = plt.subplots(figsize=(7.2, 5.0))
    ax.spines["left"].set_linewidth(1.5)
    ax.spines["right"].set_linewidth(1.5)
    ax.spines["top"].set_linewidth(1.5)
    ax.spines["bottom"].set_linewidth(1.5)

    for k_index, K in enumerate(K_list):
        y = data[prefix]["breakthrough_rank"][:, k_index]
        ax.plot(visibility_start_list, y, marker="o", linewidth=1.5, markersize=5, label=f"K={K}")

    ax.invert_yaxis()
    ax.set_xlabel("Visibility start", fontweight="bold", fontsize=12)
    ax.set_ylabel("Best solution rank (lower is better)", fontweight="bold", fontsize=12)
    ax.set_title(f"Best Rank by K: {condition_labels[prefix]} (K=4–8)", fontweight="bold", fontsize=13)
    ax.legend(frameon=False, ncol=3, fontsize=9)
    ax.grid(alpha=0.25)
    plt.tight_layout()

    output_path = result_folder / f"figure_4_{prefix}_best_rank_by_K_across_visibility_timing_K4_K8.png"
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.show()
    print("Saved:", output_path)
# Out:
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_4_gg_best_rank_by_K_across_visibility_timing_K4_K8.png
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_4_gs_best_rank_by_K_across_visibility_timing_K4_K8.png
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_4_sg_best_rank_by_K_across_visibility_timing_K4_K8.png
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_4_ss_best_rank_by_K_across_visibility_timing_K4_K8.png

# %%
# =========================
# Optional helper: inspect exact values as tables
# =========================
def timing_table(dv="breakthrough_rank", aggregate="mean"):
    """Return a condition-by-timing table for a selected DV.

    aggregate="mean" averages across K.
    aggregate=None returns the full arrays in data[prefix][dv].
    """
    if aggregate is None:
        return {prefix: data[prefix][dv] for prefix in condition_labels}
    if aggregate != "mean":
        raise ValueError("Only aggregate='mean' or aggregate=None are supported.")
    table = []
    for prefix in ["gg", "gs", "sg", "ss"]:
        row = [condition_labels[prefix]] + data[prefix][dv].mean(axis=1).round(4).tolist()
        table.append(row)
    columns = ["Condition"] + [f"start={v}" for v in visibility_start_list]
    return table, columns

table, columns = timing_table("breakthrough_rank")
print(columns)
for row in table:
    print(row)
# Out:
# ['Condition', 'start=0', 'start=50', 'start=100', 'start=150', 'start=200']
# ['G → G', 104.6906, 45.0212, 46.6775, 45.7825, 114.565]
# ['G → S', 35.3606, 33.0556, 31.48, 29.4206, 292.0338]
# ['S → G', 76.8775, 67.3981, 67.5575, 68.0131, 232.0438]
# ['S → S', 12.8812, 10.0812, 9.0625, 10.1844, 128.7888]

# %%
# =========================
# Figure 5: Integrated performance across K
# Averaged across G/S visibility recombinations and visibility timing
# =========================

fig, ax = plt.subplots(figsize=(7.2, 5.0))
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

prefixes = ["gg", "gs", "sg", "ss"]
dv = "breakthrough_fitness"

# Stack arrays with shape:
# condition × visibility_start × K
performance_stack = np.stack(
    [data[prefix][dv] for prefix in prefixes],
    axis=0
)

# Average across:
# axis=0: G/S recombination conditions
# axis=1: visibility timing
# Remaining axis is K
performance_across_K = performance_stack.mean(axis=(0, 1))

ax.plot(
    K_list,
    performance_across_K,
    marker="o",
    linewidth=2.5,
    markersize=7,
    color=morandi_blue
)

ax.set_xlabel("K", fontweight="bold", fontsize=12)
ax.set_ylabel("Best solution fitness", fontweight="bold", fontsize=12)
ax.set_title(
    "Integrated Performance Across K=4–8\nAveraged Across Visibility Direction and Timing",
    fontweight="bold",
    fontsize=13
)
ax.grid(alpha=0.25)

plt.tight_layout()

output_path = result_folder / "figure_5_integrated_performance_across_K4_K8.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
plt.show()

print("Saved:", output_path)
print("Averaged performance across K:")
for K, value in zip(K_list, performance_across_K):
    print(f"K={K}: {value:.4f}")
# Out:
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_5_integrated_performance_across_K4_K8.png
# Averaged performance across K:
# K=1: 0.9595
# K=2: 0.9521
# K=3: 0.9467
# K=4: 0.9440
# K=5: 0.9389
# K=6: 0.9370
# K=7: 0.9353
# K=8: 0.9320

# %%
# =========================
# Figure 6: Integrated breakthrough rank across K
# Averaged across G/S visibility recombinations and visibility timing
# =========================

fig, ax = plt.subplots(figsize=(7.2, 5.0))
ax.spines["left"].set_linewidth(1.5)
ax.spines["right"].set_linewidth(1.5)
ax.spines["top"].set_linewidth(1.5)
ax.spines["bottom"].set_linewidth(1.5)

prefixes = ["gg", "gs", "sg", "ss"]
dv = "breakthrough_rank"

# Stack arrays with shape:
# condition × visibility_start × K
rank_stack = np.stack(
    [data[prefix][dv] for prefix in prefixes],
    axis=0
)

# Average across:
# axis=0: G/S recombination conditions
# axis=1: visibility timing
# Remaining axis is K
rank_across_K = rank_stack.mean(axis=(0, 1))

ax.plot(
    K_list,
    rank_across_K,
    marker="o",
    linewidth=2.5,
    markersize=7,
    color=morandi_blue
)

ax.set_xlabel("K", fontweight="bold", fontsize=12)
ax.set_ylabel("Best solution rank", fontweight="bold", fontsize=12)
ax.set_title(
    "Integrated Breakthrough Rank Across K=4–8\nAveraged Across Visibility Direction and Timing",
    fontweight="bold",
    fontsize=13
)

# Because smaller rank is better: rank 1 is the global best.
ax.invert_yaxis()

ax.grid(alpha=0.25)

plt.tight_layout()

output_path = result_folder / "figure_6_integrated_breakthrough_rank_across_K4_K8.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
plt.show()

print("Saved:", output_path)
print("Averaged breakthrough rank across K:")
for K, value in zip(K_list, rank_across_K):
    print(f"K={K}: {value:.4f}")
# Out:
# Saved: /Volumes/T7/data/gst-0112-26/Timing/figure_6_integrated_breakthrough_rank_across_K4_K8.png
# Averaged breakthrough rank across K:
# K=1: 70.4068
# K=2: 64.8010
# K=3: 65.4278
# K=4: 64.4265
# K=5: 72.2417
# K=6: 77.9607
# K=7: 78.9570
# K=8: 90.1688
